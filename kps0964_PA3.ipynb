# %% [markdown]
# # PA 3: Association Analysis - Apriori Algorithm

# %% [markdown]
# ## Student Details
#
# Student Name and ID: KRUTIBEN SAVALIYA (1001660964)

# %% [markdown]
# ## Submission Instructions
#
#
# Step 1: Create a folder and name it 'yourNetID_PA3'
#
# Step 2: Rename this submission file as 'yourNetID_PA3.ipynb' and place it inside the folder 'yourNetID_PA3'
#
# Step 3: Rename the updated dataset file 'dataset.csv' and place it inside the folder 'yourNetID_PA3'
#
# Step 4: Your submission folder should include ONLY the following files:
#     * apriory.py,
#     * yourNetID_PA3.ipynb,
#     * dataset.csv,
#     * toyDS.csv
#
# Step 5: Zip this folder and submit it on BB. Your final submission folder name should be 'yourNetID_PA3.ZIP'

# %% [markdown]
# ## Programming Assignment Details
#
# Before you start:
# - Note that this is an individual assignment.
# - Be familiar with the algorithm and with the dataset.
# - If you use external sources make sure that you cite them, and be specific!
# - Make sure that your code is running before you upload your submission file. TA will not debug your code.
# - Start early!
#
#
# For this assignment, you will have to use:
# * Jupyter notebook,
# * the 'Random Shopping cart' dataset [01],
# * and the Apriori Algorithm (apriory.py)[02]. Note that the apriory.py file is modified to run with Python 3.

# %% [markdown]
# ## - - - - - - - - - - - - - - - - - - - - - - - SOLUTION - - - - - - - - - - - - - - - - - - - - - - -

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Import your Libraries
import pandas as pd
import apriori as ap

# %% [markdown]
# ### Task 1: DataSet Preprocess
# Before you start you need to modify your dataset 'dataset_group.csv' to look like the toyDS.csv.  Each transaction is at one line with a variable length.  Discard the date attribute (1st attribute) from your dataset.  For example, in your dataset transaction#4 should look like:
#
#     cereals,juice,lunch meat,soda,toilet paper,all-purpose
#
# Export your modified dataset in a file named 'dataset.csv'.
#
# Use pandas to Read and Print the first 7 transactions of the 'dataset.csv'.

# %%
from IPython.display import Image
print ('ScreenShot of the toyDS.csv')
Image("SampleScreen01.png")
# Out:
# ScreenShot of the toyDS.csv

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
df = pd.read_csv('dataset_group.csv')
df.columns= ['datum','Transaction','Item']
df1 = df.groupby('Transaction')['Item'].apply(','.join)
export_csv = df1.to_csv (r'dataset.csv', index = False, header=True)
df_data = pd.read_csv('dataset.csv')

# %%
# # #  Solution  # # #
print(df_data[:7])
# Out:
#                                                 Item
# 0  pork,sandwich bags,lunch meat,all- purpose,flo...
# 1  toilet paper,shampoo,hand soap,waffles,vegetab...
# 2  soda,pork,soap,ice cream,toilet paper,dinner r...
# 3  cereals,juice,lunch meat,soda,toilet paper,all...
# 4  sandwich loaves,pasta,tortillas,mixes,hand soa...
# 5  laundry detergent,toilet paper,eggs,toilet pap...
# 6  individual meals,paper towels,tortillas,vegeta...

# %% [markdown]
# ### Task 2: Run apriory.py and Evaluate Results
#
# In this task, you have to find how you will be able to execute and print apriory results by making use only the apriory.py. In other words "DO NOT USE ANY OTHER LIBRARY FOR TASK 2!!!".
#
# (*) For those that are not familiar with python and coding this could be a quite demanding task.
#
#
# You will have to execute apriori algorithm "3" times for different combinations of support and confidence.
# Print the results of apriory for 'dataset.csv' by making use ONLY the provided methods.
#
# Do not forget to add your reasoning (explain the result outcome) at the top of each case in a nice and readable way.
#
# You are allowed to use the python print method to print your results. DO NOT add your reasoning as comments.

# %%
print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #') 
print ('Case 1 (minimum support=0.1 and minimum confidence=0.1)')

print ('Case 1 Reasoning:')
print('The minimum values for support and confidence which could result items and rules as an output are 0.1 and 0.1 respectively.')
print('These values give maximum possible rules and items possible in from the data given.')
print('If any of support or confidence are less than 0.1, it does not calculate either item-set or rule-set.')

print ('Case 1 Output:')
# %run apriori.py -f DATASET.csv -s 0.1 -c 0.1
# Out:
# # # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #
# Case 1 (minimum support=0.1 and minimum confidence=0.1)
# Case 1 Reasoning:
# The minimum values for support and confidence which could result items and rules as an output are 0.1 and 0.1 respectively.
# These values give maximum possible rules and items possible in from the data given.
# If any of support or confidence are less than 0.1, it does not calculate either item-set or rule-set.
# Case 1 Output:
#
# ------------ITEMS-----------------
# item: ('vegetables', 'butter', 'ketchup') , 0.100
# item: ('beef', 'vegetables', 'individual meals') , 0.100
# item: ('vegetables', 'aluminum foil', 'pork') , 0.100
# item: ('vegetables', 'flour', 'shampoo') , 0.100
# item: ('vegetables', 'dishwashing liquid/detergent', 'ketchup') , 0.100
# item: ('vegetables', 'butter', 'waffles') , 0.100
# item: ('vegetables', 'sandwich bags', 'flour') , 0.100
# item: ('flour', 'sandwich loaves', 'vegetables') , 0.100
# item: ('beef', 'sandwich loaves', 'vegetables') , 0.100
# item: ('vegetables', 'all- purpose', 'shampoo') , 0.100
# item: ('sandwich loaves', 'fruits', 'vegetables') , 0.100
# item: ('vegetables', 'fruits', 'coffee/tea') , 0.100
# item: ('vegetables', 'mixes', 'fruits') , 0.100
# item: ('juice', 'sandwich bags', 'vegetables') , 0.100
# item: ('sandwich loaves', 'mixes', 'vegetables') , 0.100
# item: ('vegetables', 'sugar', 'fruits') , 0.100
# item: ('pork', 'dinner rolls', 'vegetables') , 0.100
# item: ('flour', 'vegetables', 'all- purpose') , 0.100
# item: ('vegetables', 'dishwashing liquid/detergent', 'shampoo') , 0.100
# item: ('vegetables', 'butter', 'sandwich bags') , 0.101
# item: ('vegetables', 'toilet paper', 'butter') , 0.101
# item: ('spaghetti sauce', 'vegetables', 'individual meals') , 0.101
# item: ('spaghetti sauce', 'vegetables', 'ice cream') , 0.101
# item: ('vegetables', 'cereals', 'butter') , 0.101
# item: ('vegetables', 'pork', 'ketchup') , 0.101
# item: ('hand soap', 'vegetables', 'eggs') , 0.101
# item: ('vegetables', 'all- purpose', 'pasta') , 0.101
# item: ('beef', 'vegetables', 'soda') , 0.101
# item: ('vegetables', 'all- purpose', 'coffee/tea') , 0.101
# item: ('spaghetti sauce', 'vegetables', 'ketchup') , 0.101
# item: ('vegetables', 'bagels', 'all- purpose') , 0.101
# item: ('sandwich bags', 'vegetables', 'pasta') , 0.101
# item: ('vegetables', 'butter', 'ice cream') , 0.101
# item: ('juice', 'vegetables', 'cheeses') , 0.101
# item: ('vegetables', 'tortillas', 'paper towels') , 0.101
# item: ('laundry detergent', 'vegetables', 'fruits') , 0.102
# item: ('vegetables', 'sugar', 'paper towels') , 0.102
# item: ('vegetables', 'milk', 'shampoo') , 0.102
# item: ('vegetables', 'soda', 'mixes') , 0.102
# item: ('vegetables', 'tortillas', 'sugar') , 0.102
# item: ('hand soap', 'vegetables', 'ketchup') , 0.102
# item: ('vegetables', 'cereals', 'ketchup') , 0.102
# item: ('vegetables', 'dishwashing liquid/detergent', 'pasta') , 0.102
# item: ('vegetables', 'sugar', 'individual meals') , 0.102
# item: ('sandwich bags', 'vegetables', 'coffee/tea') , 0.102
# item: ('sandwich bags', 'vegetables', 'ice cream') , 0.102
# item: ('sandwich bags', 'vegetables', 'aluminum foil') , 0.102
# item: ('beef', 'vegetables', 'waffles') , 0.102
# item: ('vegetables', 'cereals', 'flour') , 0.102
# item: ('individual meals', 'vegetables', 'coffee/tea') , 0.102
# item: ('vegetables', 'butter', 'coffee/tea') , 0.102
# item: ('pasta', 'vegetables', 'milk') , 0.102
# item: ('beef', 'bagels', 'vegetables') , 0.102
# item: ('vegetables', 'paper towels', 'bagels') , 0.102
# item: ('vegetables', 'dishwashing liquid/detergent', 'individual meals') , 0.102
# item: ('bagels', 'fruits', 'vegetables') , 0.102
# item: ('sandwich bags', 'vegetables', 'fruits') , 0.103
# item: ('soap', 'vegetables', 'fruits') , 0.103
# item: ('vegetables', 'paper towels', 'flour') , 0.103
# item: ('vegetables', 'toilet paper', 'ice cream') , 0.103
# item: ('vegetables', 'mixes', 'all- purpose') , 0.103
# item: ('vegetables', 'toilet paper', 'dishwashing liquid/detergent') , 0.103
# item: ('vegetables', 'soda', 'toilet paper') , 0.103
# item: ('sandwich loaves', 'vegetables', 'lunch meat') , 0.103
# item: ('vegetables', 'toilet paper', 'sugar') , 0.103
# item: ('vegetables', 'all- purpose', 'ketchup') , 0.103
# item: ('vegetables', 'sugar', 'milk') , 0.103
# item: ('hand soap', 'vegetables', 'individual meals') , 0.103
# item: ('sandwich bags', 'vegetables', 'dishwashing liquid/detergent') , 0.103
# item: ('laundry detergent', 'vegetables', 'sugar') , 0.103
# item: ('vegetables', 'butter', 'paper towels') , 0.103
# item: ('beef', 'vegetables', 'dishwashing liquid/detergent') , 0.103
# item: ('sandwich bags', 'vegetables', 'bagels') , 0.103
# item: ('vegetables', 'paper towels', 'individual meals') , 0.103
# item: ('vegetables', 'sugar', 'shampoo') , 0.103
# item: ('vegetables', 'tortillas', 'yogurt') , 0.103
# item: ('spaghetti sauce', 'vegetables', 'butter') , 0.103
# item: ('vegetables', 'sugar', 'coffee/tea') , 0.103
# item: ('sandwich loaves', 'vegetables', 'eggs') , 0.103
# item: ('vegetables', 'flour', 'waffles') , 0.103
# item: ('vegetables', 'fruits', 'ketchup') , 0.103
# item: ('vegetables', 'tortillas', 'eggs') , 0.103
# item: ('beef', 'vegetables', 'paper towels') , 0.103
# item: ('vegetables', 'cereals', 'sandwich bags') , 0.103
# item: ('vegetables', 'pork', 'waffles') , 0.104
# item: ('spaghetti sauce', 'sandwich loaves', 'vegetables') , 0.104
# item: ('vegetables', 'mixes', 'waffles') , 0.104
# item: ('vegetables', 'mixes', 'pork') , 0.104
# item: ('beef', 'toilet paper', 'vegetables') , 0.104
# item: ('vegetables', 'tortillas', 'lunch meat') , 0.104
# item: ('vegetables', 'bagels', 'pork') , 0.104
# item: ('vegetables', 'bagels', 'milk') , 0.104
# item: ('vegetables', 'mixes', 'bagels') , 0.104
# item: ('vegetables', 'mixes', 'individual meals') , 0.104
# item: ('vegetables', 'ice cream', 'milk') , 0.104
# item: ('vegetables', 'bagels', 'coffee/tea') , 0.104
# item: ('vegetables', 'ice cream', 'coffee/tea') , 0.104
# item: ('vegetables', 'sugar', 'soap') , 0.104
# item: ('sandwich bags', 'vegetables', 'individual meals') , 0.104
# item: ('vegetables', 'mixes', 'coffee/tea') , 0.104
# item: ('beef', 'cheeses', 'vegetables') , 0.104
# item: ('juice', 'sandwich loaves', 'vegetables') , 0.104
# item: ('vegetables', 'flour', 'milk') , 0.104
# item: ('soap', 'vegetables', 'bagels') , 0.104
# item: ('vegetables', 'ketchup', 'shampoo') , 0.104
# item: ('vegetables', 'flour', 'lunch meat') , 0.104
# item: ('sandwich loaves', 'paper towels', 'vegetables') , 0.104
# item: ('beef', 'dinner rolls', 'vegetables') , 0.104
# item: ('vegetables', 'toilet paper', 'all- purpose') , 0.104
# item: ('sandwich loaves', 'butter', 'vegetables') , 0.104
# item: ('pork', 'vegetables', 'all- purpose') , 0.104
# item: ('vegetables', 'cereals', 'sugar') , 0.104
# item: ('spaghetti sauce', 'vegetables', 'paper towels') , 0.104
# item: ('dinner rolls', 'sandwich bags', 'vegetables') , 0.104
# item: ('vegetables', 'tortillas', 'coffee/tea') , 0.104
# item: ('vegetables', 'soda', 'all- purpose') , 0.104
# item: ('vegetables', 'butter', 'lunch meat') , 0.104
# item: ('hand soap', 'vegetables', 'lunch meat') , 0.104
# item: ('vegetables', 'fruits', 'yogurt') , 0.104
# item: ('vegetables', 'cheeses', 'milk') , 0.104
# item: ('vegetables', 'ketchup', 'pasta') , 0.104
# item: ('sandwich loaves', 'sugar', 'vegetables') , 0.104
# item: ('vegetables', 'bagels', 'shampoo') , 0.104
# item: ('vegetables', 'paper towels', 'fruits') , 0.104
# item: ('beef', 'vegetables', 'milk') , 0.104
# item: ('sandwich loaves', 'cereals', 'vegetables') , 0.104
# item: ('vegetables', 'lunch meat', 'ketchup') , 0.104
# item: ('vegetables', 'butter', 'shampoo') , 0.104
# item: ('vegetables', 'cheeses', 'all- purpose') , 0.104
# item: ('vegetables', 'toilet paper', 'shampoo') , 0.104
# item: ('shampoo', 'vegetables', 'individual meals') , 0.104
# item: ('vegetables', 'cereals', 'all- purpose') , 0.104
# item: ('vegetables', 'cereals', 'bagels') , 0.104
# item: ('juice', 'vegetables', 'milk') , 0.104
# item: ('vegetables', 'soda', 'bagels') , 0.104
# item: ('sandwich loaves', 'vegetables', 'waffles') , 0.104
# item: ('vegetables', 'butter', 'aluminum foil') , 0.104
# item: ('vegetables', 'fruits', 'all- purpose') , 0.104
# item: ('beef', 'butter') , 0.105
# item: ('vegetables', 'butter', 'cheeses') , 0.105
# item: ('laundry detergent', 'vegetables', 'flour') , 0.105
# item: ('vegetables', 'ice cream', 'shampoo') , 0.105
# item: ('coffee/tea', 'vegetables', 'shampoo') , 0.105
# item: ('beef', 'vegetables', 'ketchup') , 0.105
# item: ('vegetables', 'sugar', 'aluminum foil') , 0.105
# item: ('sandwich loaves', 'vegetables', 'ketchup') , 0.105
# item: ('pork', 'vegetables', 'eggs') , 0.105
# item: ('vegetables', 'soda', 'sandwich bags') , 0.105
# item: ('vegetables', 'soda', 'ketchup') , 0.105
# item: ('vegetables', 'fruits', 'aluminum foil') , 0.105
# item: ('spaghetti sauce', 'vegetables', 'mixes') , 0.105
# item: ('vegetables', 'tortillas', 'mixes') , 0.105
# item: ('vegetables', 'butter', 'soap') , 0.106
# item: ('dinner rolls', 'tortillas', 'vegetables') , 0.106
# item: ('flour', 'vegetables', 'eggs') , 0.106
# item: ('vegetables', 'toilet paper', 'individual meals') , 0.106
# item: ('vegetables', 'ice cream', 'ketchup') , 0.106
# item: ('sandwich loaves', 'soap', 'vegetables') , 0.106
# item: ('juice', 'vegetables', 'pork') , 0.106
# item: ('vegetables', 'mixes', 'soap') , 0.106
# item: ('vegetables', 'cheeses', 'dishwashing liquid/detergent') , 0.106
# item: ('sandwich bags', 'vegetables', 'lunch meat') , 0.106
# item: ('vegetables', 'ketchup', 'milk') , 0.106
# item: ('vegetables', 'cereals', 'soda') , 0.106
# item: ('vegetables', 'pork', 'coffee/tea') , 0.106
# item: ('juice', 'vegetables', 'dishwashing liquid/detergent') , 0.106
# item: ('laundry detergent', 'vegetables', 'coffee/tea') , 0.106
# item: ('dinner rolls', 'butter', 'vegetables') , 0.106
# item: ('laundry detergent', 'vegetables', 'pasta') , 0.106
# item: ('beef', 'vegetables', 'shampoo') , 0.106
# item: ('sandwich loaves', 'vegetables', 'coffee/tea') , 0.106
# item: ('hand soap', 'dinner rolls', 'vegetables') , 0.106
# item: ('vegetables', 'fruits', 'cheeses') , 0.106
# item: ('vegetables', 'bagels', 'yogurt') , 0.106
# item: ('hand soap', 'vegetables', 'poultry') , 0.106
# item: ('vegetables', 'fruits', 'milk') , 0.106
# item: ('vegetables', 'toilet paper', 'paper towels') , 0.107
# item: ('milk', 'vegetables', 'coffee/tea') , 0.107
# item: ('laundry detergent', 'vegetables', 'individual meals') , 0.107
# item: ('sandwich bags', 'vegetables', 'milk') , 0.107
# item: ('vegetables', 'bagels', 'ketchup') , 0.107
# item: ('sandwich loaves', 'aluminum foil', 'vegetables') , 0.107
# item: ('laundry detergent', 'vegetables', 'bagels') , 0.107
# item: ('vegetables', 'soap', 'flour') , 0.107
# item: ('juice', 'vegetables', 'all- purpose') , 0.107
# item: ('vegetables', 'paper towels', 'waffles') , 0.107
# item: ('vegetables', 'sugar', 'eggs') , 0.107
# item: ('juice', 'beef', 'vegetables') , 0.107
# item: ('juice', 'vegetables', 'cereals') , 0.107
# item: ('laundry detergent', 'vegetables', 'toilet paper') , 0.107
# item: ('sandwich loaves', 'soda', 'vegetables') , 0.107
# item: ('spaghetti sauce', 'vegetables', 'cheeses') , 0.107
# item: ('beef', 'sugar', 'vegetables') , 0.107
# item: ('vegetables', 'pork', 'lunch meat') , 0.107
# item: ('vegetables', 'aluminum foil', 'lunch meat') , 0.107
# item: ('vegetables', 'soda', 'coffee/tea') , 0.107
# item: ('coffee/tea', 'vegetables', 'pasta') , 0.107
# item: ('beef', 'soap', 'vegetables') , 0.107
# item: ('vegetables', 'aluminum foil', 'pasta') , 0.107
# item: ('soap', 'vegetables', 'aluminum foil') , 0.107
# item: ('dinner rolls', 'vegetables', 'individual meals') , 0.107
# item: ('vegetables', 'bagels', 'waffles') , 0.107
# item: ('vegetables', 'toilet paper', 'dinner rolls') , 0.107
# item: ('vegetables', 'all- purpose', 'milk') , 0.107
# item: ('vegetables', 'pork', 'yogurt') , 0.107
# item: ('juice', 'vegetables', 'soda') , 0.107
# item: ('vegetables', 'fruits', 'ice cream') , 0.107
# item: ('dinner rolls', 'vegetables', 'all- purpose') , 0.107
# item: ('spaghetti sauce', 'vegetables', 'pork') , 0.107
# item: ('vegetables', 'toilet paper', 'ketchup') , 0.108
# item: ('laundry detergent', 'vegetables', 'paper towels') , 0.108
# item: ('vegetables', 'toilet paper', 'cheeses') , 0.108
# item: ('sandwich bags', 'vegetables', 'ketchup') , 0.108
# item: ('vegetables', 'paper towels', 'pasta') , 0.108
# item: ('vegetables', 'flour', 'coffee/tea') , 0.108
# item: ('vegetables', 'mixes', 'cheeses') , 0.108
# item: ('vegetables', 'fruits', 'waffles') , 0.108
# item: ('vegetables', 'aluminum foil', 'individual meals') , 0.108
# item: ('vegetables', 'mixes', 'shampoo') , 0.108
# item: ('vegetables', 'sugar', 'cheeses') , 0.108
# item: ('sandwich bags', 'vegetables', 'shampoo') , 0.108
# item: ('sandwich loaves', 'dinner rolls', 'vegetables') , 0.108
# item: ('dinner rolls', 'vegetables', 'coffee/tea') , 0.108
# item: ('juice', 'vegetables', 'mixes') , 0.108
# item: ('vegetables', 'cereals', 'individual meals') , 0.108
# item: ('vegetables', 'sandwich bags', 'eggs') , 0.108
# item: ('vegetables', 'paper towels', 'cheeses') , 0.108
# item: ('vegetables', 'soap', 'yogurt') , 0.108
# item: ('dinner rolls', 'vegetables', 'ice cream') , 0.108
# item: ('juice', 'vegetables', 'individual meals') , 0.108
# item: ('juice', 'vegetables', 'butter') , 0.108
# item: ('hand soap', 'butter') , 0.109
# item: ('dinner rolls', 'soap', 'vegetables') , 0.109
# item: ('beef', 'vegetables', 'lunch meat') , 0.109
# item: ('vegetables', 'paper towels', 'dishwashing liquid/detergent') , 0.109
# item: ('vegetables', 'butter', 'mixes') , 0.109
# item: ('vegetables', 'toilet paper', 'waffles') , 0.109
# item: ('vegetables', 'toilet paper', 'mixes') , 0.109
# item: ('vegetables', 'soda', 'sugar') , 0.109
# item: ('vegetables', 'all- purpose', 'dishwashing liquid/detergent') , 0.109
# item: ('vegetables', 'soap', 'dishwashing liquid/detergent') , 0.109
# item: ('vegetables', 'soap', 'shampoo') , 0.109
# item: ('vegetables', 'bagels', 'cheeses') , 0.109
# item: ('poultry', 'vegetables', 'fruits') , 0.109
# item: ('vegetables', 'cheeses', 'shampoo') , 0.109
# item: ('vegetables', 'eggs', 'shampoo') , 0.109
# item: ('vegetables', 'soda', 'shampoo') , 0.109
# item: ('vegetables', 'ice cream', 'yogurt') , 0.109
# item: ('vegetables', 'lunch meat', 'shampoo') , 0.109
# item: ('vegetables', 'mixes', 'lunch meat') , 0.109
# item: ('vegetables', 'toilet paper', 'yogurt') , 0.109
# item: ('vegetables', 'ice cream', 'pasta') , 0.109
# item: ('dinner rolls', 'vegetables', 'milk') , 0.109
# item: ('vegetables', 'lunch meat', 'all- purpose') , 0.109
# item: ('vegetables', 'toilet paper', 'bagels') , 0.109
# item: ('dinner rolls', 'bagels', 'vegetables') , 0.110
# item: ('shampoo', 'vegetables', 'yogurt') , 0.110
# item: ('spaghetti sauce', 'vegetables', 'aluminum foil') , 0.110
# item: ('laundry detergent', 'vegetables', 'spaghetti sauce') , 0.110
# item: ('vegetables', 'soap', 'coffee/tea') , 0.110
# item: ('vegetables', 'soap', 'ice cream') , 0.110
# item: ('vegetables', 'bagels', 'ice cream') , 0.110
# item: ('vegetables', 'waffles', 'pasta') , 0.110
# item: ('vegetables', 'aluminum foil', 'all- purpose') , 0.110
# item: ('vegetables', 'paper towels', 'shampoo') , 0.110
# item: ('vegetables', 'cereals', 'ice cream') , 0.110
# item: ('vegetables', 'toilet paper', 'lunch meat') , 0.110
# item: ('vegetables', 'paper towels', 'coffee/tea') , 0.110
# item: ('vegetables', 'toilet paper', 'coffee/tea') , 0.110
# item: ('vegetables', 'dishwashing liquid/detergent', 'coffee/tea') , 0.110
# item: ('spaghetti sauce', 'vegetables', 'yogurt') , 0.110
# item: ('sandwich loaves', 'pork') , 0.111
# item: ('fruits', 'pork') , 0.111
# item: ('bagels', 'flour') , 0.111
# item: ('vegetables', 'soda', 'flour') , 0.111
# item: ('vegetables', 'toilet paper', 'aluminum foil') , 0.111
# item: ('vegetables', 'eggs', 'individual meals') , 0.111
# item: ('spaghetti sauce', 'vegetables', 'cereals') , 0.111
# item: ('vegetables', 'fruits', 'eggs') , 0.111
# item: ('vegetables', 'soap', 'milk') , 0.111
# item: ('poultry', 'vegetables', 'waffles') , 0.111
# item: ('vegetables', 'ice cream', 'individual meals') , 0.111
# item: ('vegetables', 'mixes', 'milk') , 0.111
# item: ('vegetables', 'cereals', 'waffles') , 0.111
# item: ('spaghetti sauce', 'vegetables', 'pasta') , 0.111
# item: ('poultry', 'vegetables', 'tortillas') , 0.111
# item: ('beef', 'aluminum foil', 'vegetables') , 0.111
# item: ('vegetables', 'aluminum foil', 'coffee/tea') , 0.111
# item: ('laundry detergent', 'vegetables', 'butter') , 0.111
# item: ('laundry detergent', 'vegetables', 'lunch meat') , 0.111
# item: ('vegetables', 'toilet paper', 'milk') , 0.111
# item: ('vegetables', 'soap', 'pasta') , 0.111
# item: ('vegetables', 'paper towels', 'sandwich bags') , 0.111
# item: ('dinner rolls', 'vegetables', 'pasta') , 0.111
# item: ('vegetables', 'ketchup', 'yogurt') , 0.111
# item: ('vegetables', 'eggs', 'ice cream') , 0.111
# item: ('vegetables', 'soap', 'all- purpose') , 0.111
# item: ('vegetables', 'sugar', 'flour') , 0.111
# item: ('vegetables', 'all- purpose', 'ice cream') , 0.111
# item: ('vegetables', 'mixes', 'flour') , 0.111
# item: ('vegetables', 'mixes', 'yogurt') , 0.111
# item: ('juice', 'vegetables', 'lunch meat') , 0.111
# item: ('hand soap', 'flour') , 0.111
# item: ('sandwich bags', 'sugar') , 0.111
# item: ('sandwich loaves', 'dishwashing liquid/detergent') , 0.111
# item: ('hand soap', 'bagels') , 0.111
# item: ('hand soap', 'all- purpose') , 0.111
# item: ('butter', 'pasta') , 0.111
# item: ('juice', 'vegetables', 'toilet paper') , 0.111
# item: ('beef', 'vegetables', 'fruits') , 0.111
# item: ('vegetables', 'soda', 'paper towels') , 0.111
# item: ('vegetables', 'mixes', 'eggs') , 0.111
# item: ('vegetables', 'lunch meat', 'milk') , 0.111
# item: ('vegetables', 'paper towels', 'yogurt') , 0.111
# item: ('vegetables', 'paper towels', 'milk') , 0.111
# item: ('vegetables', 'fruits', 'lunch meat') , 0.111
# item: ('poultry', 'vegetables', 'beef') , 0.111
# item: ('vegetables', 'cereals', 'shampoo') , 0.111
# item: ('laundry detergent', 'vegetables', 'ice cream') , 0.111
# item: ('sandwich loaves', 'cheeses', 'vegetables') , 0.111
# item: ('beef', 'vegetables', 'eggs') , 0.111
# item: ('juice', 'vegetables', 'coffee/tea') , 0.111
# item: ('dinner rolls', 'vegetables', 'lunch meat') , 0.111
# item: ('vegetables', 'bagels', 'lunch meat') , 0.111
# item: ('spaghetti sauce', 'vegetables', 'bagels') , 0.111
# item: ('vegetables', 'cereals', 'fruits') , 0.111
# item: ('shampoo', 'vegetables', 'waffles') , 0.111
# item: ('vegetables', 'dishwashing liquid/detergent', 'ice cream') , 0.111
# item: ('juice', 'vegetables', 'soap') , 0.111
# item: ('vegetables', 'sugar', 'ice cream') , 0.111
# item: ('vegetables', 'paper towels', 'soap') , 0.111
# item: ('dinner rolls', 'vegetables', 'ketchup') , 0.111
# item: ('vegetables', 'lunch meat', 'coffee/tea') , 0.111
# item: ('vegetables', 'cheeses', 'pasta') , 0.111
# item: ('beef', 'vegetables', 'cereals') , 0.111
# item: ('vegetables', 'cereals', 'pasta') , 0.111
# item: ('hand soap', 'pork') , 0.112
# item: ('hand soap', 'soap') , 0.112
# item: ('vegetables', 'toilet paper', 'soap') , 0.112
# item: ('poultry', 'vegetables', 'butter') , 0.112
# item: ('vegetables', 'cereals', 'milk') , 0.112
# item: ('dinner rolls', 'vegetables', 'dishwashing liquid/detergent') , 0.112
# item: ('flour', 'dinner rolls', 'vegetables') , 0.112
# item: ('vegetables', 'soda', 'dishwashing liquid/detergent') , 0.112
# item: ('spaghetti sauce', 'vegetables', 'lunch meat') , 0.112
# item: ('vegetables', 'aluminum foil', 'dishwashing liquid/detergent') , 0.112
# item: ('spaghetti sauce', 'vegetables', 'soap') , 0.112
# item: ('vegetables', 'aluminum foil', 'flour') , 0.112
# item: ('vegetables', 'bagels', 'individual meals') , 0.112
# item: ('vegetables', 'soap', 'individual meals') , 0.112
# item: ('sandwich bags', 'soap', 'vegetables') , 0.112
# item: ('vegetables', 'cereals', 'dinner rolls') , 0.112
# item: ('vegetables', 'cheeses', 'lunch meat') , 0.112
# item: ('vegetables', 'mixes', 'dinner rolls') , 0.112
# item: ('juice', 'vegetables', 'ice cream') , 0.112
# item: ('poultry', 'vegetables', 'sandwich bags') , 0.112
# item: ('poultry', 'vegetables', 'flour') , 0.112
# item: ('vegetables', 'sugar', 'dishwashing liquid/detergent') , 0.112
# item: ('vegetables', 'paper towels', 'ice cream') , 0.112
# item: ('vegetables', 'soda', 'cheeses') , 0.112
# item: ('vegetables', 'aluminum foil', 'ketchup') , 0.112
# item: ('sandwich loaves', 'vegetables', 'yogurt') , 0.112
# item: ('vegetables', 'cereals', 'soap') , 0.112
# item: ('tortillas', 'shampoo') , 0.113
# item: ('hand soap', 'toilet paper') , 0.113
# item: ('tortillas', 'fruits') , 0.113
# item: ('laundry detergent', 'vegetables', 'mixes') , 0.113
# item: ('vegetables', 'yogurt', 'individual meals') , 0.113
# item: ('coffee/tea', 'vegetables', 'yogurt') , 0.113
# item: ('vegetables', 'cheeses', 'flour') , 0.113
# item: ('sandwich loaves', 'vegetables', 'individual meals') , 0.113
# item: ('dinner rolls', 'paper towels', 'vegetables') , 0.113
# item: ('vegetables', 'butter', 'eggs') , 0.113
# item: ('vegetables', 'cheeses', 'individual meals') , 0.113
# item: ('beef', 'vegetables', 'yogurt') , 0.113
# item: ('vegetables', 'all- purpose', 'waffles') , 0.113
# item: ('laundry detergent', 'vegetables', 'dishwashing liquid/detergent') , 0.113
# item: ('vegetables', 'soda', 'lunch meat') , 0.113
# item: ('vegetables', 'flour', 'ketchup') , 0.113
# item: ('poultry', 'vegetables', 'pasta') , 0.113
# item: ('sandwich bags', 'vegetables', 'yogurt') , 0.113
# item: ('sandwich loaves', 'vegetables', 'shampoo') , 0.113
# item: ('laundry detergent', 'sandwich loaves') , 0.114
# item: ('hand soap', 'paper towels') , 0.114
# item: ('hand soap', 'fruits') , 0.114
# item: ('hand soap', 'aluminum foil') , 0.114
# item: ('butter', 'yogurt') , 0.114
# item: ('hand soap', 'sandwich loaves') , 0.114
# item: ('spaghetti sauce', 'vegetables', 'soda') , 0.114
# item: ('vegetables', 'cereals', 'cheeses') , 0.114
# item: ('laundry detergent', 'vegetables', 'soap') , 0.114
# item: ('vegetables', 'lunch meat', 'yogurt') , 0.114
# item: ('vegetables', 'fruits', 'dishwashing liquid/detergent') , 0.114
# item: ('vegetables', 'aluminum foil', 'milk') , 0.114
# item: ('vegetables', 'sugar', 'yogurt') , 0.114
# item: ('vegetables', 'aluminum foil', 'shampoo') , 0.114
# item: ('juice', 'vegetables', 'bagels') , 0.114
# item: ('vegetables', 'ketchup', 'coffee/tea') , 0.114
# item: ('dinner rolls', 'vegetables', 'shampoo') , 0.114
# item: ('sandwich loaves', 'vegetables', 'ice cream') , 0.114
# item: ('vegetables', 'cereals', 'toilet paper') , 0.114
# item: ('beef', 'vegetables', 'ice cream') , 0.114
# item: ('vegetables', 'yogurt', 'pasta') , 0.114
# item: ('individual meals', 'vegetables', 'waffles') , 0.114
# item: ('poultry', 'vegetables', 'bagels') , 0.114
# item: ('vegetables', 'soda', 'ice cream') , 0.114
# item: ('vegetables', 'waffles', 'ice cream') , 0.114
# item: ('laundry detergent', 'vegetables', 'soda') , 0.114
# item: ('hand soap', 'tortillas') , 0.115
# item: ('hand soap', 'sugar') , 0.115
# item: ('spaghetti sauce', 'tortillas') , 0.115
# item: ('sugar', 'pork') , 0.115
# item: ('sandwich loaves', 'milk') , 0.115
# item: ('laundry detergent', 'vegetables', 'aluminum foil') , 0.115
# item: ('poultry', 'vegetables', 'pork') , 0.115
# item: ('vegetables', 'dishwashing liquid/detergent', 'yogurt') , 0.115
# item: ('vegetables', 'toilet paper', 'eggs') , 0.115
# item: ('juice', 'vegetables', 'paper towels') , 0.115
# item: ('vegetables', 'eggs', 'coffee/tea') , 0.115
# item: ('laundry detergent', 'vegetables', 'milk') , 0.115
# item: ('paper towels', 'vegetables', 'mixes') , 0.115
# item: ('vegetables', 'dishwashing liquid/detergent', 'milk') , 0.115
# item: ('vegetables', 'cereals', 'aluminum foil') , 0.115
# item: ('dinner rolls', 'sugar', 'vegetables') , 0.115
# item: ('sandwich loaves', 'eggs') , 0.116
# item: ('lunch meat', 'pasta') , 0.116
# item: ('sandwich loaves', 'pasta') , 0.116
# item: ('spaghetti sauce', 'shampoo') , 0.116
# item: ('laundry detergent', 'vegetables', 'eggs') , 0.116
# item: ('vegetables', 'soda', 'milk') , 0.116
# item: ('vegetables', 'mixes', 'ketchup') , 0.116
# item: ('juice', 'vegetables', 'waffles') , 0.116
# item: ('sandwich bags', 'vegetables', 'waffles') , 0.116
# item: ('dinner rolls', 'aluminum foil', 'vegetables') , 0.116
# item: ('vegetables', 'aluminum foil', 'eggs') , 0.116
# item: ('vegetables', 'paper towels', 'ketchup') , 0.116
# item: ('laundry detergent', 'vegetables', 'ketchup') , 0.116
# item: ('butter', 'flour') , 0.117
# item: ('hand soap', 'sandwich bags') , 0.117
# item: ('juice', 'flour') , 0.117
# item: ('pork', 'pasta') , 0.117
# item: ('vegetables', 'eggs', 'lunch meat') , 0.117
# item: ('vegetables', 'paper towels', 'all- purpose') , 0.117
# item: ('spaghetti sauce', 'vegetables', 'eggs') , 0.117
# item: ('vegetables', 'cheeses', 'ketchup') , 0.117
# item: ('vegetables', 'ketchup', 'waffles') , 0.117
# item: ('laundry detergent', 'vegetables', 'cheeses') , 0.117
# item: ('vegetables', 'cereals', 'coffee/tea') , 0.117
# item: ('vegetables', 'cereals', 'mixes') , 0.117
# item: ('vegetables', 'cereals', 'paper towels') , 0.117
# item: ('vegetables', 'sugar', 'waffles') , 0.117
# item: ('laundry detergent', 'vegetables', 'all- purpose') , 0.117
# item: ('vegetables', 'bagels', 'dishwashing liquid/detergent') , 0.117
# item: ('poultry', 'vegetables', 'ketchup') , 0.117
# item: ('laundry detergent', 'vegetables', 'waffles') , 0.117
# item: ('spaghetti sauce', 'dishwashing liquid/detergent') , 0.118
# item: ('tortillas', 'all- purpose') , 0.118
# item: ('spaghetti sauce', 'flour') , 0.118
# item: ('butter', 'sugar') , 0.118
# item: ('butter', 'fruits') , 0.118
# item: ('toilet paper', 'fruits') , 0.118
# item: ('spaghetti sauce', 'sugar') , 0.118
# item: ('hand soap', 'yogurt') , 0.118
# item: ('hand soap', 'spaghetti sauce') , 0.118
# item: ('beef', 'flour') , 0.118
# item: ('vegetables', 'sugar', 'lunch meat') , 0.118
# item: ('vegetables', 'soap', 'ketchup') , 0.118
# item: ('vegetables', 'soda', 'waffles') , 0.118
# item: ('juice', 'vegetables', 'ketchup') , 0.118
# item: ('vegetables', 'waffles', 'coffee/tea') , 0.118
# item: ('poultry', 'vegetables', 'toilet paper') , 0.118
# item: ('laundry detergent', 'vegetables', 'yogurt') , 0.118
# item: ('vegetables', 'lunch meat', 'ice cream') , 0.118
# item: ('vegetables', 'flour', 'yogurt') , 0.118
# item: ('vegetables', 'dishwashing liquid/detergent', 'waffles') , 0.118
# item: ('vegetables', 'cheeses', 'aluminum foil') , 0.118
# item: ('vegetables', 'soda', 'aluminum foil') , 0.118
# item: ('vegetables', 'soda', 'pasta') , 0.118
# item: ('sugar', 'ketchup') , 0.118
# item: ('hand soap', 'soda') , 0.118
# item: ('butter', 'pork') , 0.118
# item: ('hand soap', 'shampoo') , 0.118
# item: ('pork', 'milk') , 0.118
# item: ('hand soap', 'pasta') , 0.118
# item: ('spaghetti sauce', 'sandwich bags') , 0.118
# item: ('tortillas', 'flour') , 0.118
# item: ('all- purpose', 'individual meals') , 0.118
# item: ('hand soap', 'dishwashing liquid/detergent') , 0.118
# item: ('laundry detergent', 'sandwich bags', 'vegetables') , 0.118
# item: ('vegetables', 'mixes', 'dishwashing liquid/detergent') , 0.118
# item: ('vegetables', 'all- purpose', 'eggs') , 0.118
# item: ('dinner rolls', 'vegetables', 'yogurt') , 0.118
# item: ('soap', 'vegetables', 'cheeses') , 0.118
# item: ('vegetables', 'soap', 'lunch meat') , 0.118
# item: ('vegetables', 'cheeses', 'coffee/tea') , 0.118
# item: ('spaghetti sauce', 'vegetables', 'waffles') , 0.118
# item: ('vegetables', 'paper towels', 'aluminum foil') , 0.118
# item: ('vegetables', 'dishwashing liquid/detergent', 'lunch meat') , 0.118
# item: ('spaghetti sauce', 'dinner rolls', 'vegetables') , 0.118
# item: ('tortillas', 'pasta') , 0.119
# item: ('juice', 'fruits') , 0.119
# item: ('tortillas', 'cheeses') , 0.119
# item: ('pork', 'ice cream') , 0.119
# item: ('sandwich loaves', 'tortillas') , 0.119
# item: ('hand soap', 'juice') , 0.119
# item: ('sandwich loaves', 'flour') , 0.119
# item: ('vegetables', 'aluminum foil', 'ice cream') , 0.119
# item: ('vegetables', 'eggs', 'dishwashing liquid/detergent') , 0.119
# item: ('juice', 'dinner rolls', 'vegetables') , 0.119
# item: ('vegetables', 'cereals', 'eggs') , 0.119
# item: ('vegetables', 'all- purpose', 'yogurt') , 0.119
# item: ('vegetables', 'paper towels', 'lunch meat') , 0.119
# item: ('vegetables', 'lunch meat', 'individual meals') , 0.119
# item: ('spaghetti sauce', 'vegetables', 'poultry') , 0.119
# item: ('poultry', 'vegetables', 'paper towels') , 0.119
# item: ('juice', 'vegetables', 'laundry detergent') , 0.119
# item: ('hand soap', 'cereals') , 0.120
# item: ('butter', 'milk') , 0.120
# item: ('pasta', 'individual meals') , 0.120
# item: ('hand soap', 'eggs') , 0.120
# item: ('vegetables', 'cereals', 'dishwashing liquid/detergent') , 0.120
# item: ('sandwich bags', 'vegetables', 'cheeses') , 0.120
# item: ('vegetables', 'soap', 'waffles') , 0.120
# item: ('poultry', 'vegetables', 'individual meals') , 0.120
# item: ('vegetables', 'bagels', 'aluminum foil') , 0.120
# item: ('vegetables', 'aluminum foil', 'waffles') , 0.120
# item: ('laundry detergent', 'vegetables', 'shampoo') , 0.120
# item: ('poultry', 'vegetables', 'all- purpose') , 0.120
# item: ('laundry detergent', 'dinner rolls', 'vegetables') , 0.120
# item: ('beef', 'all- purpose') , 0.121
# item: ('sugar', 'milk') , 0.121
# item: ('fruits', 'pasta') , 0.121
# item: ('hand soap', 'beef') , 0.121
# item: ('hand soap', 'cheeses') , 0.121
# item: ('hand soap', 'ice cream') , 0.121
# item: ('laundry detergent', 'hand soap') , 0.121
# item: ('tortillas', 'pork') , 0.121
# item: ('laundry detergent', 'pork') , 0.121
# item: ('sandwich bags', 'flour') , 0.121
# item: ('sandwich loaves', 'sandwich bags') , 0.121
# item: ('tortillas', 'dishwashing liquid/detergent') , 0.121
# item: ('sugar', 'pasta') , 0.121
# item: ('dinner rolls', 'cheeses', 'vegetables') , 0.121
# item: ('vegetables', 'yogurt', 'waffles') , 0.121
# item: ('vegetables', 'paper towels', 'eggs') , 0.121
# item: ('vegetables', 'soda', 'individual meals') , 0.121
# item: ('vegetables', 'cheeses', 'ice cream') , 0.121
# item: ('vegetables', 'cereals', 'yogurt') , 0.121
# item: ('spaghetti sauce', 'vegetables', 'juice') , 0.121
# item: ('laundry detergent', 'tortillas') , 0.122
# item: ('paper towels', 'pork') , 0.122
# item: ('beef', 'tortillas') , 0.122
# item: ('tortillas', 'ice cream') , 0.122
# item: ('flour', 'shampoo') , 0.122
# item: ('paper towels', 'flour') , 0.122
# item: ('pork', 'flour') , 0.122
# item: ('pasta', 'shampoo') , 0.122
# item: ('fruits', 'flour') , 0.122
# item: ('mixes', 'sugar') , 0.122
# item: ('butter', 'dishwashing liquid/detergent') , 0.122
# item: ('flour', 'lunch meat') , 0.122
# item: ('poultry', 'vegetables', 'shampoo') , 0.122
# item: ('vegetables', 'eggs', 'pasta') , 0.122
# item: ('vegetables', 'soda', 'yogurt') , 0.122
# item: ('vegetables', 'bagels', 'eggs') , 0.122
# item: ('vegetables', 'soda', 'soap') , 0.122
# item: ('vegetables', 'eggs', 'ketchup') , 0.122
# item: ('sandwich loaves', 'bagels') , 0.123
# item: ('sugar', 'bagels') , 0.123
# item: ('pork', 'shampoo') , 0.123
# item: ('sandwich loaves', 'fruits') , 0.123
# item: ('toilet paper', 'pasta') , 0.123
# item: ('juice', 'pasta') , 0.123
# item: ('sandwich loaves', 'toilet paper') , 0.123
# item: ('sandwich bags', 'toilet paper') , 0.123
# item: ('paper towels', 'sugar') , 0.123
# item: ('sandwich loaves', 'lunch meat') , 0.123
# item: ('laundry detergent', 'beef') , 0.123
# item: ('toilet paper', 'pork') , 0.123
# item: ('butter', 'aluminum foil') , 0.123
# item: ('dinner rolls', 'fruits') , 0.123
# item: ('fruits', 'individual meals') , 0.123
# item: ('sugar', 'all- purpose') , 0.123
# item: ('spaghetti sauce', 'coffee/tea') , 0.123
# item: ('mixes', 'pasta') , 0.123
# item: ('juice', 'tortillas') , 0.123
# item: ('tortillas', 'yogurt') , 0.123
# item: ('poultry', 'sandwich loaves', 'vegetables') , 0.123
# item: ('poultry', 'vegetables', 'milk') , 0.123
# item: ('juice', 'vegetables', 'shampoo') , 0.123
# item: ('juice', 'vegetables', 'yogurt') , 0.123
# item: ('vegetables', 'milk', 'yogurt') , 0.123
# item: ('juice', 'vegetables', 'aluminum foil') , 0.123
# item: ('vegetables', 'soap', 'eggs') , 0.123
# item: ('vegetables', 'eggs', 'milk') , 0.123
# item: ('vegetables', 'cereals', 'lunch meat') , 0.123
# item: ('hand soap', 'individual meals') , 0.124
# item: ('hand soap', 'lunch meat') , 0.124
# item: ('flour', 'pasta') , 0.124
# item: ('pork', 'lunch meat') , 0.124
# item: ('dishwashing liquid/detergent', 'shampoo') , 0.124
# item: ('bagels', 'pasta') , 0.124
# item: ('pork', 'individual meals') , 0.124
# item: ('fruits', 'shampoo') , 0.124
# item: ('flour', 'ice cream') , 0.124
# item: ('tortillas', 'aluminum foil') , 0.124
# item: ('shampoo', 'milk') , 0.124
# item: ('hand soap', 'ketchup') , 0.124
# item: ('tortillas', 'sugar') , 0.124
# item: ('poultry', 'vegetables', 'cereals') , 0.124
# item: ('vegetables', 'eggs', 'waffles') , 0.124
# item: ('vegetables', 'cheeses', 'waffles') , 0.124
# item: ('poultry', 'vegetables', 'cheeses') , 0.124
# item: ('sandwich bags', 'pasta') , 0.125
# item: ('sandwich loaves', 'paper towels') , 0.125
# item: ('soap', 'pork') , 0.125
# item: ('juice', 'milk') , 0.125
# item: ('flour', 'eggs') , 0.125
# item: ('hand soap', 'coffee/tea') , 0.125
# item: ('juice', 'sugar') , 0.125
# item: ('spaghetti sauce', 'all- purpose') , 0.125
# item: ('spaghetti sauce', 'pork') , 0.125
# item: ('beef', 'individual meals') , 0.125
# item: ('hand soap', 'waffles') , 0.125
# item: ('sandwich bags', 'eggs') , 0.125
# item: ('toilet paper', 'flour') , 0.125
# item: ('butter', 'ketchup') , 0.125
# item: ('flour', 'individual meals') , 0.125
# item: ('juice', 'butter') , 0.125
# item: ('poultry', 'vegetables', 'soda') , 0.125
# item: ('juice', 'vegetables', 'eggs') , 0.125
# item: ('vegetables', 'cheeses', 'yogurt') , 0.125
# item: ('individual meals', 'milk') , 0.125
# item: ('sugar', 'aluminum foil') , 0.125
# item: ('tortillas', 'butter') , 0.125
# item: ('butter', 'ice cream') , 0.125
# item: ('sandwich loaves', 'mixes') , 0.125
# item: ('ketchup', 'individual meals') , 0.125
# item: ('butter', 'individual meals') , 0.125
# item: ('sandwich loaves', 'all- purpose') , 0.125
# item: ('sandwich bags', 'butter') , 0.125
# item: ('butter', 'all- purpose') , 0.125
# item: ('laundry detergent', 'flour') , 0.125
# item: ('beef', 'pasta') , 0.125
# item: ('sandwich loaves', 'butter') , 0.125
# item: ('laundry detergent', 'vegetables', 'cereals') , 0.125
# item: ('vegetables', 'mixes', 'aluminum foil') , 0.125
# item: ('poultry', 'vegetables', 'yogurt') , 0.125
# item: ('hand soap', 'mixes') , 0.126
# item: ('juice', 'sandwich bags') , 0.126
# item: ('aluminum foil', 'lunch meat') , 0.126
# item: ('lunch meat', 'ketchup') , 0.126
# item: ('soda', 'butter') , 0.126
# item: ('sandwich bags', 'all- purpose') , 0.126
# item: ('juice', 'cheeses') , 0.126
# item: ('beef', 'sandwich loaves') , 0.126
# item: ('sandwich bags', 'individual meals') , 0.126
# item: ('cereals', 'butter') , 0.126
# item: ('tortillas', 'eggs') , 0.126
# item: ('butter', 'bagels') , 0.126
# item: ('sandwich bags', 'aluminum foil') , 0.126
# item: ('tortillas', 'soap') , 0.126
# item: ('laundry detergent', 'coffee/tea') , 0.126
# item: ('cereals', 'flour') , 0.126
# item: ('sugar', 'shampoo') , 0.126
# item: ('tortillas', 'waffles') , 0.126
# item: ('butter', 'coffee/tea') , 0.126
# item: ('pork', 'dishwashing liquid/detergent') , 0.126
# item: ('sugar', 'flour') , 0.126
# item: ('flour', 'all- purpose') , 0.126
# item: ('vegetables', 'soda', 'dinner rolls') , 0.126
# item: ('poultry', 'vegetables', 'coffee/tea') , 0.126
# item: ('pasta', 'milk') , 0.127
# item: ('sandwich loaves', 'dinner rolls') , 0.127
# item: ('sandwich loaves', 'sugar') , 0.127
# item: ('sandwich loaves', 'waffles') , 0.127
# item: ('laundry detergent', 'fruits') , 0.127
# item: ('butter', 'waffles') , 0.127
# item: ('laundry detergent', 'sugar') , 0.127
# item: ('spaghetti sauce', 'ice cream') , 0.127
# item: ('sugar', 'individual meals') , 0.127
# item: ('tortillas', 'individual meals') , 0.127
# item: ('tortillas', 'cereals') , 0.127
# item: ('sandwich loaves', 'coffee/tea') , 0.127
# item: ('dinner rolls', 'pork') , 0.127
# item: ('tortillas', 'milk') , 0.127
# item: ('juice', 'dishwashing liquid/detergent') , 0.127
# item: ('vegetables', 'cheeses', 'eggs') , 0.127
# item: ('poultry', 'vegetables', 'lunch meat') , 0.127
# item: ('poultry', 'vegetables', 'aluminum foil') , 0.127
# item: ('dishwashing liquid/detergent', 'flour') , 0.128
# item: ('sugar', 'dishwashing liquid/detergent') , 0.128
# item: ('sugar', 'fruits') , 0.128
# item: ('spaghetti sauce', 'beef') , 0.128
# item: ('flour', 'waffles') , 0.128
# item: ('beef', 'pork') , 0.128
# item: ('beef', 'coffee/tea') , 0.128
# item: ('tortillas', 'ketchup') , 0.128
# item: ('sugar', 'eggs') , 0.128
# item: ('poultry', 'vegetables', 'ice cream') , 0.128
# item: ('waffles', 'milk') , 0.129
# item: ('flour', 'milk') , 0.129
# item: ('tortillas', 'lunch meat') , 0.129
# item: ('dishwashing liquid/detergent', 'ketchup') , 0.129
# item: ('bagels', 'all- purpose') , 0.129
# item: ('aluminum foil', 'pasta') , 0.129
# item: ('spaghetti sauce', 'toilet paper') , 0.129
# item: ('hand soap', 'milk') , 0.129
# item: ('mixes', 'ice cream') , 0.129
# item: ('soda', 'all- purpose') , 0.129
# item: ('laundry detergent', 'butter') , 0.129
# item: ('spaghetti sauce', 'fruits') , 0.129
# item: ('toilet paper', 'dishwashing liquid/detergent') , 0.129
# item: ('pork', 'eggs') , 0.129
# item: ('laundry detergent', 'paper towels') , 0.129
# item: ('spaghetti sauce', 'butter') , 0.129
# item: ('bagels', 'yogurt') , 0.129
# item: ('spaghetti sauce', 'milk') , 0.129
# item: ('poultry', 'vegetables', 'sugar') , 0.129
# item: ('dinner rolls', 'vegetables', 'waffles') , 0.129
# item: ('poultry', 'vegetables', 'soap') , 0.129
# item: ('eggs', 'individual meals') , 0.130
# item: ('toilet paper', 'sugar') , 0.130
# item: ('sandwich bags', 'pork') , 0.130
# item: ('butter', 'paper towels') , 0.130
# item: ('cheeses', 'pork') , 0.130
# item: ('tortillas', 'toilet paper') , 0.130
# item: ('fruits', 'coffee/tea') , 0.130
# item: ('soda', 'fruits') , 0.130
# item: ('soda', 'pork') , 0.130
# item: ('sandwich loaves', 'ketchup') , 0.130
# item: ('sandwich bags', 'ice cream') , 0.130
# item: ('pork', 'yogurt') , 0.130
# item: ('ketchup', 'yogurt') , 0.130
# item: ('laundry detergent', 'pasta') , 0.130
# item: ('sandwich loaves', 'aluminum foil') , 0.130
# item: ('sandwich bags', 'dinner rolls') , 0.130
# item: ('fruits', 'ketchup') , 0.130
# item: ('cereals', 'ketchup') , 0.130
# item: ('tortillas', 'soda') , 0.130
# item: ('fruits', 'eggs') , 0.130
# item: ('dinner rolls', 'vegetables', 'eggs') , 0.130
# item: ('beef', 'mixes') , 0.131
# item: ('sandwich bags', 'lunch meat') , 0.131
# item: ('soap', 'yogurt') , 0.131
# item: ('sandwich loaves', 'soda') , 0.131
# item: ('sandwich bags', 'mixes') , 0.131
# item: ('dishwashing liquid/detergent', 'yogurt') , 0.131
# item: ('soda', 'lunch meat') , 0.131
# item: ('all- purpose', 'shampoo') , 0.131
# item: ('sandwich bags', 'dishwashing liquid/detergent') , 0.131
# item: ('laundry detergent', 'spaghetti sauce') , 0.131
# item: ('all- purpose', 'coffee/tea') , 0.131
# item: ('pork', 'ketchup') , 0.131
# item: ('spaghetti sauce', 'paper towels') , 0.131
# item: ('butter', 'shampoo') , 0.131
# item: ('sugar', 'coffee/tea') , 0.131
# item: ('sandwich bags', 'bagels') , 0.131
# item: ('juice', 'sandwich loaves') , 0.131
# item: ('mixes', 'waffles') , 0.131
# item: ('sandwich bags', 'coffee/tea') , 0.131
# item: ('laundry detergent', 'ice cream') , 0.131
# item: ('eggs', 'shampoo') , 0.131
# item: ('all- purpose', 'milk') , 0.131
# item: ('sandwich bags', 'shampoo') , 0.131
# item: ('fruits', 'soap') , 0.131
# item: ('vegetables', 'aluminum foil', 'yogurt') , 0.131
# item: ('poultry', 'vegetables', 'juice') , 0.131
# item: ('laundry detergent', 'vegetables', 'poultry') , 0.131
# item: ('spaghetti sauce', 'sandwich loaves') , 0.132
# item: ('cheeses', 'all- purpose') , 0.132
# item: ('paper towels', 'yogurt') , 0.132
# item: ('cereals', 'pork') , 0.132
# item: ('juice', 'mixes') , 0.132
# item: ('paper towels', 'fruits') , 0.132
# item: ('hand soap', 'dinner rolls') , 0.132
# item: ('dinner rolls', 'butter') , 0.132
# item: ('aluminum foil', 'pork') , 0.132
# item: ('soda', 'shampoo') , 0.132
# item: ('cheeses', 'dishwashing liquid/detergent') , 0.132
# item: ('paper towels', 'bagels') , 0.132
# item: ('bagels', 'soap') , 0.132
# item: ('ice cream', 'yogurt') , 0.132
# item: ('cereals', 'sugar') , 0.132
# item: ('dinner rolls', 'lunch meat') , 0.132
# item: ('shampoo', 'coffee/tea') , 0.132
# item: ('lunch meat', 'shampoo') , 0.132
# item: ('soap', 'flour') , 0.132
# item: ('butter', 'mixes') , 0.132
# item: ('poultry', 'vegetables', 'eggs') , 0.132
# item: ('paper towels', 'shampoo') , 0.132
# item: ('juice', 'lunch meat') , 0.132
# item: ('beef', 'bagels') , 0.132
# item: ('spaghetti sauce', 'yogurt') , 0.132
# item: ('cheeses', 'pasta') , 0.132
# item: ('bagels', 'pork') , 0.132
# item: ('eggs', 'lunch meat') , 0.132
# item: ('beef', 'dishwashing liquid/detergent') , 0.132
# item: ('spaghetti sauce', 'ketchup') , 0.132
# item: ('cheeses', 'milk') , 0.132
# item: ('flour', 'coffee/tea') , 0.132
# item: ('dinner rolls', 'toilet paper') , 0.132
# item: ('hand soap', 'poultry') , 0.132
# item: ('tortillas', 'paper towels') , 0.132
# item: ('sandwich loaves', 'yogurt') , 0.132
# item: ('laundry detergent', 'individual meals') , 0.132
# item: ('laundry detergent', 'bagels') , 0.132
# item: ('sandwich loaves', 'cereals') , 0.132
# item: ('beef', 'paper towels') , 0.132
# item: ('laundry detergent', 'toilet paper') , 0.132
# item: ('mixes', 'fruits') , 0.132
# item: ('ice cream', 'shampoo') , 0.132
# item: ('all- purpose', 'pasta') , 0.132
# item: ('beef', 'soda') , 0.132
# item: ('pork', 'waffles') , 0.132
# item: ('spaghetti sauce', 'individual meals') , 0.132
# item: ('fruits', 'milk') , 0.132
# item: ('mixes', 'coffee/tea') , 0.132
# item: ('vegetables', 'eggs', 'yogurt') , 0.132
# item: ('poultry', 'vegetables', 'mixes') , 0.132
# item: ('lunch meat', 'all- purpose') , 0.133
# item: ('cheeses', 'shampoo') , 0.133
# item: ('bagels', 'shampoo') , 0.133
# item: ('toilet paper', 'all- purpose') , 0.133
# item: ('bagels', 'coffee/tea') , 0.133
# item: ('beef', 'waffles') , 0.133
# item: ('yogurt', 'pasta') , 0.133
# item: ('fruits', 'yogurt') , 0.133
# item: ('individual meals', 'coffee/tea') , 0.133
# item: ('bagels', 'milk') , 0.133
# item: ('poultry', 'flour') , 0.133
# item: ('sugar', 'soap') , 0.133
# item: ('sugar', 'ice cream') , 0.133
# item: ('mixes', 'soap') , 0.133
# item: ('mixes', 'bagels') , 0.133
# item: ('flour', 'ketchup') , 0.133
# item: ('mixes', 'pork') , 0.133
# item: ('laundry detergent', 'lunch meat') , 0.133
# item: ('all- purpose', 'ice cream') , 0.133
# item: ('paper towels', 'dishwashing liquid/detergent') , 0.133
# item: ('mixes', 'flour') , 0.133
# item: ('beef', 'shampoo') , 0.133
# item: ('tortillas', 'bagels') , 0.133
# item: ('dinner rolls', 'all- purpose') , 0.133
# item: ('spaghetti sauce', 'pasta') , 0.133
# item: ('pasta', 'coffee/tea') , 0.133
# item: ('milk', 'coffee/tea') , 0.133
# item: ('paper towels', 'pasta') , 0.133
# item: ('yogurt', 'shampoo') , 0.133
# item: ('dishwashing liquid/detergent', 'individual meals') , 0.133
# item: ('soda', 'sugar') , 0.133
# item: ('dinner rolls', 'milk') , 0.133
# item: ('fruits', 'aluminum foil') , 0.133
# item: ('butter', 'eggs') , 0.133
# item: ('dinner rolls', 'tortillas') , 0.133
# item: ('mixes', 'all- purpose') , 0.133
# item: ('cereals', 'all- purpose') , 0.133
# item: ('aluminum foil', 'flour') , 0.133
# item: ('soda', 'bagels') , 0.134
# item: ('pork', 'coffee/tea') , 0.134
# item: ('aluminum foil', 'shampoo') , 0.134
# item: ('bagels', 'lunch meat') , 0.134
# item: ('cereals', 'soda') , 0.134
# item: ('soda', 'mixes') , 0.134
# item: ('beef', 'ketchup') , 0.134
# item: ('shampoo', 'individual meals') , 0.134
# item: ('toilet paper', 'butter') , 0.134
# item: ('aluminum foil', 'all- purpose') , 0.134
# item: ('beef', 'dinner rolls') , 0.134
# item: ('soap', 'aluminum foil') , 0.134
# item: ('lunch meat', 'milk') , 0.134
# item: ('toilet paper', 'ice cream') , 0.134
# item: ('dinner rolls', 'flour') , 0.134
# item: ('bagels', 'waffles') , 0.134
# item: ('paper towels', 'individual meals') , 0.134
# item: ('soda', 'flour') , 0.134
# item: ('lunch meat', 'yogurt') , 0.134
# item: ('paper towels', 'cheeses') , 0.134
# item: ('dishwashing liquid/detergent', 'pasta') , 0.134
# item: ('dinner rolls', 'individual meals') , 0.134
# item: ('toilet paper', 'shampoo') , 0.134
# item: ('aluminum foil', 'eggs') , 0.134
# item: ('beef', 'milk') , 0.134
# item: ('beef', 'eggs') , 0.134
# item: ('dinner rolls', 'bagels') , 0.134
# item: ('vegetables', 'lunch meat', 'waffles') , 0.134
# item: ('bagels', 'fruits') , 0.135
# item: ('sandwich bags', 'ketchup') , 0.135
# item: ('sandwich bags', 'yogurt') , 0.135
# item: ('beef', 'cheeses') , 0.135
# item: ('tortillas', 'coffee/tea') , 0.135
# item: ('ketchup', 'shampoo') , 0.135
# item: ('poultry', 'pasta') , 0.135
# item: ('bagels', 'ketchup') , 0.135
# item: ('all- purpose', 'ketchup') , 0.135
# item: ('sugar', 'cheeses') , 0.135
# item: ('ketchup', 'milk') , 0.135
# item: ('ice cream', 'ketchup') , 0.135
# item: ('ice cream', 'milk') , 0.135
# item: ('butter', 'soap') , 0.135
# item: ('butter', 'cheeses') , 0.135
# item: ('mixes', 'individual meals') , 0.135
# item: ('juice', 'coffee/tea') , 0.135
# item: ('beef', 'sugar') , 0.135
# item: ('laundry detergent', 'aluminum foil') , 0.135
# item: ('sandwich bags', 'paper towels') , 0.135
# item: ('pork', 'all- purpose') , 0.135
# item: ('soda', 'paper towels') , 0.135
# item: ('toilet paper', 'mixes') , 0.135
# item: ('sandwich loaves', 'soap') , 0.135
# item: ('spaghetti sauce', 'aluminum foil') , 0.135
# item: ('poultry', 'vegetables', 'dishwashing liquid/detergent') , 0.135
# item: ('vegetables', 'soda', 'eggs') , 0.135
# item: ('sandwich loaves', 'shampoo') , 0.136
# item: ('mixes', 'eggs') , 0.136
# item: ('paper towels', 'coffee/tea') , 0.136
# item: ('beef', 'lunch meat') , 0.136
# item: ('cheeses', 'lunch meat') , 0.136
# item: ('toilet paper', 'yogurt') , 0.136
# item: ('laundry detergent', 'yogurt') , 0.136
# item: ('juice', 'beef') , 0.136
# item: ('ice cream', 'pasta') , 0.136
# item: ('fruits', 'all- purpose') , 0.136
# item: ('laundry detergent', 'ketchup') , 0.136
# item: ('sandwich bags', 'tortillas') , 0.136
# item: ('spaghetti sauce', 'soda') , 0.136
# item: ('toilet paper', 'ketchup') , 0.136
# item: ('laundry detergent', 'cheeses') , 0.136
# item: ('dinner rolls', 'ice cream') , 0.136
# item: ('spaghetti sauce', 'cheeses') , 0.136
# item: ('fruits', 'lunch meat') , 0.136
# item: ('paper towels', 'ketchup') , 0.136
# item: ('soap', 'shampoo') , 0.136
# item: ('aluminum foil', 'ketchup') , 0.137
# item: ('shampoo', 'waffles') , 0.137
# item: ('beef', 'yogurt') , 0.137
# item: ('sandwich bags', 'cereals') , 0.137
# item: ('laundry detergent', 'soda') , 0.137
# item: ('cereals', 'bagels') , 0.137
# item: ('aluminum foil', 'dishwashing liquid/detergent') , 0.137
# item: ('dinner rolls', 'pasta') , 0.137
# item: ('toilet paper', 'bagels') , 0.137
# item: ('laundry detergent', 'waffles') , 0.137
# item: ('spaghetti sauce', 'mixes') , 0.137
# item: ('sandwich loaves', 'cheeses') , 0.137
# item: ('juice', 'paper towels') , 0.137
# item: ('juice', 'pork') , 0.137
# item: ('soda', 'ketchup') , 0.137
# item: ('mixes', 'shampoo') , 0.137
# item: ('sandwich bags', 'fruits') , 0.137
# item: ('eggs', 'coffee/tea') , 0.138
# item: ('beef', 'aluminum foil') , 0.138
# item: ('cereals', 'pasta') , 0.138
# item: ('mixes', 'cheeses') , 0.138
# item: ('beef', 'sandwich bags') , 0.138
# item: ('beef', 'soap') , 0.138
# item: ('juice', 'all- purpose') , 0.138
# item: ('mixes', 'lunch meat') , 0.138
# item: ('cereals', 'shampoo') , 0.138
# item: ('spaghetti sauce', 'lunch meat') , 0.138
# item: ('juice', 'soda') , 0.138
# item: ('juice', 'cereals') , 0.138
# item: ('spaghetti sauce', 'eggs') , 0.138
# item: ('laundry detergent', 'mixes') , 0.138
# item: ('spaghetti sauce', 'soap') , 0.138
# item: ('toilet paper', 'aluminum foil') , 0.138
# item: ('ice cream', 'coffee/tea') , 0.138
# item: ('eggs', 'all- purpose') , 0.138
# item: ('laundry detergent', 'juice') , 0.138
# item: ('mixes', 'yogurt') , 0.138
# item: ('soda', 'toilet paper') , 0.138
# item: ('spaghetti sauce', 'bagels') , 0.138
# item: ('toilet paper', 'individual meals') , 0.138
# item: ('laundry detergent', 'eggs') , 0.138
# item: ('poultry', 'dinner rolls', 'vegetables') , 0.138
# item: ('ketchup', 'pasta') , 0.139
# item: ('soap', 'pasta') , 0.139
# item: ('juice', 'soap') , 0.139
# item: ('yogurt', 'individual meals') , 0.139
# item: ('dishwashing liquid/detergent', 'coffee/tea') , 0.139
# item: ('sugar', 'lunch meat') , 0.139
# item: ('dinner rolls', 'dishwashing liquid/detergent') , 0.139
# item: ('butter', 'lunch meat') , 0.139
# item: ('fruits', 'waffles') , 0.139
# item: ('bagels', 'ice cream') , 0.139
# item: ('dinner rolls', 'paper towels') , 0.139
# item: ('poultry', 'butter') , 0.139
# item: ('laundry detergent', 'shampoo') , 0.139
# item: ('laundry detergent', 'soap') , 0.139
# ...
# Rule: ('soda', 'cheeses') ==> ('vegetables',) , 0.805
# Rule: ('toilet paper', 'mixes') ==> ('vegetables',) , 0.805
# Rule: ('sandwich bags', 'aluminum foil') ==> ('vegetables',) , 0.806
# Rule: ('cereals', 'flour') ==> ('vegetables',) , 0.806
# Rule: ('butter', 'coffee/tea') ==> ('vegetables',) , 0.806
# Rule: ('cheeses', 'waffles') ==> ('vegetables',) , 0.806
# Rule: ('poultry', 'ketchup') ==> ('vegetables',) , 0.806
# Rule: ('cheeses', 'flour') ==> ('vegetables',) , 0.806
# Rule: ('laundry detergent', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.806
# Rule: ('paper towels', 'coffee/tea') ==> ('vegetables',) , 0.806
# Rule: ('cheeses', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.807
# Rule: ('dinner rolls', 'butter') ==> ('vegetables',) , 0.807
# Rule: ('hand soap', 'dinner rolls') ==> ('vegetables',) , 0.807
# Rule: ('laundry detergent', 'sugar') ==> ('vegetables',) , 0.807
# Rule: ('poultry', 'toilet paper') ==> ('vegetables',) , 0.807
# Rule: ('juice', 'bagels') ==> ('vegetables',) , 0.807
# Rule: ('dinner rolls', 'pasta') ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent', 'individual meals') ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent', 'bagels') ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent', 'toilet paper') ==> ('vegetables',) , 0.808
# Rule: ('dinner rolls', 'toilet paper') ==> ('vegetables',) , 0.808
# Rule: ('dishwashing liquid/detergent', 'lunch meat') ==> ('vegetables',) , 0.808
# Rule: ('dishwashing liquid/detergent', 'shampoo') ==> ('vegetables',) , 0.809
# Rule: ('toilet paper', 'eggs') ==> ('vegetables',) , 0.809
# Rule: ('cereals', 'shampoo') ==> ('vegetables',) , 0.809
# Rule: ('spaghetti sauce', 'bagels') ==> ('vegetables',) , 0.809
# Rule: ('cereals', 'pasta') ==> ('vegetables',) , 0.809
# Rule: ('paper towels', 'pasta') ==> ('vegetables',) , 0.809
# Rule: ('soda', 'all- purpose') ==> ('vegetables',) , 0.810
# Rule: ('juice', 'waffles') ==> ('vegetables',) , 0.810
# Rule: ('sandwich bags', 'pasta') ==> ('vegetables',) , 0.810
# Rule: ('poultry', 'butter') ==> ('vegetables',) , 0.810
# Rule: ('dinner rolls', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.810
# Rule: ('sandwich loaves', 'ketchup') ==> ('vegetables',) , 0.811
# Rule: ('bagels', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.811
# Rule: ('cheeses', 'individual meals') ==> ('vegetables',) , 0.811
# Rule: ('eggs',) ==> ('vegetables',) , 0.811
# Rule: ('poultry', 'soda') ==> ('vegetables',) , 0.811
# Rule: ('spaghetti sauce', 'aluminum foil') ==> ('vegetables',) , 0.812
# Rule: ('dinner rolls', 'cheeses') ==> ('vegetables',) , 0.812
# Rule: ('cheeses', 'ice cream') ==> ('vegetables',) , 0.812
# Rule: ('sandwich bags', 'lunch meat') ==> ('vegetables',) , 0.812
# Rule: ('soda', 'pasta') ==> ('vegetables',) , 0.812
# Rule: ('aluminum foil', 'milk') ==> ('vegetables',) , 0.812
# Rule: ('sandwich loaves', 'ice cream') ==> ('vegetables',) , 0.812
# Rule: ('sugar', 'shampoo') ==> ('vegetables',) , 0.812
# Rule: ('tortillas', 'eggs') ==> ('vegetables',) , 0.812
# Rule: ('soap', 'flour') ==> ('vegetables',) , 0.813
# Rule: ('laundry detergent', 'milk') ==> ('vegetables',) , 0.814
# Rule: ('juice', 'shampoo') ==> ('vegetables',) , 0.814
# Rule: ('sandwich loaves', 'cheeses') ==> ('vegetables',) , 0.814
# Rule: ('waffles', 'shampoo') ==> ('vegetables',) , 0.814
# Rule: ('sandwich loaves', 'fruits') ==> ('vegetables',) , 0.814
# Rule: ('flour', 'coffee/tea') ==> ('vegetables',) , 0.815
# Rule: ('spaghetti sauce', 'lunch meat') ==> ('vegetables',) , 0.815
# Rule: ('spaghetti sauce', 'soap') ==> ('vegetables',) , 0.815
# Rule: ('sandwich bags', 'cheeses') ==> ('vegetables',) , 0.815
# Rule: ('paper towels', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.816
# Rule: ('soda', 'sugar') ==> ('vegetables',) , 0.816
# Rule: ('cheeses', 'shampoo') ==> ('vegetables',) , 0.816
# Rule: ('dinner rolls', 'milk') ==> ('vegetables',) , 0.816
# Rule: ('lunch meat', 'all- purpose') ==> ('vegetables',) , 0.816
# Rule: ('cheeses', 'ketchup') ==> ('vegetables',) , 0.816
# Rule: ('pork', 'eggs') ==> ('vegetables',) , 0.816
# Rule: ('individual meals', 'yogurt') ==> ('vegetables',) , 0.816
# Rule: ('yogurt', 'coffee/tea') ==> ('vegetables',) , 0.816
# Rule: ('sandwich loaves', 'individual meals') ==> ('vegetables',) , 0.816
# Rule: ('dinner rolls', 'paper towels') ==> ('vegetables',) , 0.816
# Rule: ('soda', 'individual meals') ==> ('vegetables',) , 0.817
# Rule: ('dinner rolls', 'bagels') ==> ('vegetables',) , 0.817
# Rule: ('aluminum foil', 'all- purpose') ==> ('vegetables',) , 0.817
# Rule: ('mixes', 'aluminum foil') ==> ('vegetables',) , 0.817
# Rule: ('laundry detergent', 'pasta') ==> ('vegetables',) , 0.818
# Rule: ('sugar', 'yogurt') ==> ('vegetables',) , 0.818
# Rule: ('poultry', 'bagels') ==> ('vegetables',) , 0.818
# Rule: ('sandwich bags', 'paper towels') ==> ('vegetables',) , 0.818
# Rule: ('spaghetti sauce', 'waffles') ==> ('vegetables',) , 0.818
# Rule: ('paper towels', 'aluminum foil') ==> ('vegetables',) , 0.818
# Rule: ('cereals', 'lunch meat') ==> ('vegetables',) , 0.819
# Rule: ('dinner rolls', 'sugar') ==> ('vegetables',) , 0.819
# Rule: ('sandwich loaves', 'soda') ==> ('vegetables',) , 0.819
# Rule: ('all- purpose', 'milk') ==> ('vegetables',) , 0.819
# Rule: ('aluminum foil', 'ice cream') ==> ('vegetables',) , 0.819
# Rule: ('paper towels', 'lunch meat') ==> ('vegetables',) , 0.819
# Rule: ('spaghetti sauce', 'poultry') ==> ('vegetables',) , 0.819
# Rule: ('mixes', 'eggs') ==> ('vegetables',) , 0.819
# Rule: ('fruits', 'lunch meat') ==> ('vegetables',) , 0.819
# Rule: ('sandwich bags', 'individual meals') ==> ('vegetables',) , 0.819
# Rule: ('sandwich bags', 'waffles') ==> ('vegetables',) , 0.820
# Rule: ('juice', 'mixes') ==> ('vegetables',) , 0.820
# Rule: ('flour', 'shampoo') ==> ('vegetables',) , 0.820
# Rule: ('poultry', 'individual meals') ==> ('vegetables',) , 0.820
# Rule: ('aluminum foil', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.821
# Rule: ('aluminum foil', 'ketchup') ==> ('vegetables',) , 0.821
# Rule: ('sandwich loaves', 'sugar') ==> ('vegetables',) , 0.821
# Rule: ('sandwich loaves', 'waffles') ==> ('vegetables',) , 0.821
# Rule: ('sugar', 'waffles') ==> ('vegetables',) , 0.821
# Rule: ('waffles', 'yogurt') ==> ('vegetables',) , 0.821
# Rule: ('laundry detergent', 'mixes') ==> ('vegetables',) , 0.822
# Rule: ('cheeses', 'aluminum foil') ==> ('vegetables',) , 0.822
# Rule: ('soda', 'aluminum foil') ==> ('vegetables',) , 0.822
# Rule: ('yogurt', 'shampoo') ==> ('vegetables',) , 0.822
# Rule: ('shampoo', 'milk') ==> ('vegetables',) , 0.823
# Rule: ('tortillas', 'sugar') ==> ('vegetables',) , 0.823
# Rule: ('hand soap', 'ketchup') ==> ('vegetables',) , 0.823
# Rule: ('laundry detergent', 'soap') ==> ('vegetables',) , 0.823
# Rule: ('bagels', 'yogurt') ==> ('vegetables',) , 0.823
# Rule: ('dinner rolls', 'yogurt') ==> ('vegetables',) , 0.823
# Rule: ('soda', 'flour') ==> ('vegetables',) , 0.824
# Rule: ('sandwich loaves', 'aluminum foil') ==> ('vegetables',) , 0.824
# Rule: ('pork', 'yogurt') ==> ('vegetables',) , 0.824
# Rule: ('eggs', 'waffles') ==> ('vegetables',) , 0.825
# Rule: ('soda', 'paper towels') ==> ('vegetables',) , 0.825
# Rule: ('juice', 'coffee/tea') ==> ('vegetables',) , 0.825
# Rule: ('dinner rolls', 'aluminum foil') ==> ('vegetables',) , 0.825
# Rule: ('sandwich loaves', 'butter') ==> ('vegetables',) , 0.825
# Rule: ('sandwich bags', 'shampoo') ==> ('vegetables',) , 0.826
# Rule: ('soap', 'yogurt') ==> ('vegetables',) , 0.826
# Rule: ('cheeses', 'yogurt') ==> ('vegetables',) , 0.826
# Rule: ('cheeses', 'lunch meat') ==> ('vegetables',) , 0.826
# Rule: ('paper towels', 'all- purpose') ==> ('vegetables',) , 0.826
# Rule: ('sandwich bags', 'flour') ==> ('vegetables',) , 0.826
# Rule: ('laundry detergent', 'all- purpose') ==> ('vegetables',) , 0.826
# Rule: ('poultry', 'dinner rolls') ==> ('vegetables',) , 0.826
# Rule: ('lunch meat', 'ketchup') ==> ('vegetables',) , 0.826
# Rule: ('butter', 'mixes') ==> ('vegetables',) , 0.827
# Rule: ('soda', 'shampoo') ==> ('vegetables',) , 0.827
# Rule: ('yogurt', 'ice cream') ==> ('vegetables',) , 0.827
# Rule: ('lunch meat', 'shampoo') ==> ('vegetables',) , 0.827
# Rule: ('beef', 'yogurt') ==> ('vegetables',) , 0.827
# Rule: ('lunch meat', 'ice cream') ==> ('vegetables',) , 0.827
# Rule: ('poultry', 'shampoo') ==> ('vegetables',) , 0.827
# Rule: ('paper towels', 'shampoo') ==> ('vegetables',) , 0.828
# Rule: ('spaghetti sauce', 'yogurt') ==> ('vegetables',) , 0.828
# Rule: ('soda', 'eggs') ==> ('vegetables',) , 0.828
# Rule: ('paper towels', 'sugar') ==> ('vegetables',) , 0.829
# Rule: ('spaghetti sauce', 'pasta') ==> ('vegetables',) , 0.829
# Rule: ('laundry detergent', 'lunch meat') ==> ('vegetables',) , 0.829
# Rule: ('all- purpose', 'ice cream') ==> ('vegetables',) , 0.829
# Rule: ('mixes', 'flour') ==> ('vegetables',) , 0.829
# Rule: ('poultry', 'paper towels') ==> ('vegetables',) , 0.829
# Rule: ('poultry', 'ice cream') ==> ('vegetables',) , 0.830
# Rule: ('hand soap', 'individual meals') ==> ('vegetables',) , 0.830
# Rule: ('aluminum foil', 'pasta') ==> ('vegetables',) , 0.830
# Rule: ('lunch meat', 'milk') ==> ('vegetables',) , 0.830
# Rule: ('beef', 'eggs') ==> ('vegetables',) , 0.830
# Rule: ('bagels', 'lunch meat') ==> ('vegetables',) , 0.830
# Rule: ('aluminum foil', 'waffles') ==> ('vegetables',) , 0.830
# Rule: ('sandwich loaves', 'paper towels') ==> ('vegetables',) , 0.831
# Rule: ('spaghetti sauce', 'juice') ==> ('vegetables',) , 0.831
# Rule: ('eggs', 'shampoo') ==> ('vegetables',) , 0.832
# Rule: ('sandwich loaves', 'shampoo') ==> ('vegetables',) , 0.832
# Rule: ('soda', 'yogurt') ==> ('vegetables',) , 0.832
# Rule: ('eggs', 'ketchup') ==> ('vegetables',) , 0.832
# Rule: ('poultry', 'coffee/tea') ==> ('vegetables',) , 0.832
# Rule: ('laundry detergent', 'poultry') ==> ('vegetables',) , 0.832
# Rule: ('soap', 'lunch meat') ==> ('vegetables',) , 0.833
# Rule: ('laundry detergent', 'soda') ==> ('vegetables',) , 0.833
# Rule: ('all- purpose', 'yogurt') ==> ('vegetables',) , 0.834
# Rule: ('eggs', 'coffee/tea') ==> ('vegetables',) , 0.834
# Rule: ('juice', 'lunch meat') ==> ('vegetables',) , 0.834
# Rule: ('juice', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.834
# Rule: ('sandwich loaves', 'coffee/tea') ==> ('vegetables',) , 0.834
# Rule: ('poultry', 'sugar') ==> ('vegetables',) , 0.835
# Rule: ('bagels', 'aluminum foil') ==> ('vegetables',) , 0.835
# Rule: ('sugar', 'ice cream') ==> ('vegetables',) , 0.836
# Rule: ('sugar', 'eggs') ==> ('vegetables',) , 0.836
# Rule: ('sandwich loaves', 'lunch meat') ==> ('vegetables',) , 0.836
# Rule: ('tortillas', 'yogurt') ==> ('vegetables',) , 0.836
# Rule: ('lunch meat', 'waffles') ==> ('vegetables',) , 0.836
# Rule: ('dinner rolls', 'flour') ==> ('vegetables',) , 0.837
# Rule: ('laundry detergent', 'paper towels') ==> ('vegetables',) , 0.837
# Rule: ('eggs', 'pasta') ==> ('vegetables',) , 0.837
# Rule: ('bagels', 'eggs') ==> ('vegetables',) , 0.837
# Rule: ('poultry', 'pasta') ==> ('vegetables',) , 0.838
# Rule: ('sandwich bags', 'yogurt') ==> ('vegetables',) , 0.838
# Rule: ('juice', 'milk') ==> ('vegetables',) , 0.838
# Rule: ('sandwich loaves', 'flour') ==> ('vegetables',) , 0.838
# Rule: ('juice', 'yogurt') ==> ('vegetables',) , 0.838
# Rule: ('spaghetti sauce', 'soda') ==> ('vegetables',) , 0.839
# Rule: ('laundry detergent', 'spaghetti sauce') ==> ('vegetables',) , 0.839
# Rule: ('laundry detergent', 'flour') ==> ('vegetables',) , 0.839
# Rule: ('sugar', 'aluminum foil') ==> ('vegetables',) , 0.839
# Rule: ('hand soap', 'eggs') ==> ('vegetables',) , 0.839
# Rule: ('juice', 'paper towels') ==> ('vegetables',) , 0.840
# Rule: ('laundry detergent', 'coffee/tea') ==> ('vegetables',) , 0.840
# Rule: ('laundry detergent', 'dinner rolls') ==> ('vegetables',) , 0.840
# Rule: ('laundry detergent', 'eggs') ==> ('vegetables',) , 0.841
# Rule: ('cheeses', 'pasta') ==> ('vegetables',) , 0.841
# Rule: ('paper towels', 'flour') ==> ('vegetables',) , 0.842
# Rule: ('dinner rolls', 'soda') ==> ('vegetables',) , 0.842
# Rule: ('aluminum foil', 'flour') ==> ('vegetables',) , 0.842
# Rule: ('poultry', 'flour') ==> ('vegetables',) , 0.842
# Rule: ('juice', 'ketchup') ==> ('vegetables',) , 0.843
# Rule: ('flour', 'yogurt') ==> ('vegetables',) , 0.843
# Rule: ('poultry', 'aluminum foil') ==> ('vegetables',) , 0.843
# Rule: ('juice', 'aluminum foil') ==> ('vegetables',) , 0.843
# Rule: ('poultry', 'mixes') ==> ('vegetables',) , 0.844
# Rule: ('hand soap', 'lunch meat') ==> ('vegetables',) , 0.844
# Rule: ('cereals', 'eggs') ==> ('vegetables',) , 0.845
# Rule: ('poultry', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.846
# Rule: ('poultry', 'yogurt') ==> ('vegetables',) , 0.846
# Rule: ('paper towels', 'yogurt') ==> ('vegetables',) , 0.847
# Rule: ('dinner rolls', 'lunch meat') ==> ('vegetables',) , 0.847
# Rule: ('spaghetti sauce', 'eggs') ==> ('vegetables',) , 0.847
# Rule: ('aluminum foil', 'lunch meat') ==> ('vegetables',) , 0.847
# Rule: ('poultry', 'eggs') ==> ('vegetables',) , 0.847
# Rule: ('sandwich loaves', 'yogurt') ==> ('vegetables',) , 0.848
# Rule: ('sugar', 'milk') ==> ('vegetables',) , 0.848
# Rule: ('poultry', 'lunch meat') ==> ('vegetables',) , 0.848
# Rule: ('sugar', 'lunch meat') ==> ('vegetables',) , 0.848
# Rule: ('sandwich loaves', 'dinner rolls') ==> ('vegetables',) , 0.848
# Rule: ('poultry', 'sandwich loaves') ==> ('vegetables',) , 0.848
# Rule: ('soap', 'eggs') ==> ('vegetables',) , 0.848
# Rule: ('butter', 'eggs') ==> ('vegetables',) , 0.849
# Rule: ('flour', 'ketchup') ==> ('vegetables',) , 0.849
# Rule: ('flour', 'lunch meat') ==> ('vegetables',) , 0.849
# Rule: ('laundry detergent', 'sandwich bags') ==> ('vegetables',) , 0.849
# Rule: ('lunch meat', 'yogurt') ==> ('vegetables',) , 0.850
# Rule: ('aluminum foil', 'shampoo') ==> ('vegetables',) , 0.850
# Rule: ('butter', 'aluminum foil') ==> ('vegetables',) , 0.850
# Rule: ('laundry detergent', 'aluminum foil') ==> ('vegetables',) , 0.851
# Rule: ('eggs', 'individual meals') ==> ('vegetables',) , 0.851
# Rule: ('fruits', 'eggs') ==> ('vegetables',) , 0.851
# Rule: ('yogurt', 'ketchup') ==> ('vegetables',) , 0.851
# Rule: ('aluminum foil', 'yogurt') ==> ('vegetables',) , 0.851
# Rule: ('paper towels', 'ketchup') ==> ('vegetables',) , 0.852
# Rule: ('laundry detergent', 'ketchup') ==> ('vegetables',) , 0.852
# Rule: ('flour', 'eggs') ==> ('vegetables',) , 0.852
# Rule: ('laundry detergent', 'ice cream') ==> ('vegetables',) , 0.852
# Rule: ('laundry detergent', 'waffles') ==> ('vegetables',) , 0.853
# Rule: ('eggs', 'milk') ==> ('vegetables',) , 0.854
# Rule: ('pasta', 'yogurt') ==> ('vegetables',) , 0.855
# Rule: ('laundry detergent', 'cereals') ==> ('vegetables',) , 0.856
# Rule: ('poultry', 'juice') ==> ('vegetables',) , 0.856
# Rule: ('laundry detergent', 'butter') ==> ('vegetables',) , 0.857
# Rule: ('laundry detergent', 'cheeses') ==> ('vegetables',) , 0.858
# Rule: ('spaghetti sauce', 'pork') ==> ('vegetables',) , 0.859
# Rule: ('dinner rolls', 'waffles') ==> ('vegetables',) , 0.860
# Rule: ('all- purpose', 'eggs') ==> ('vegetables',) , 0.860
# Rule: ('dinner rolls', 'eggs') ==> ('vegetables',) , 0.860
# Rule: ('dishwashing liquid/detergent', 'eggs') ==> ('vegetables',) , 0.861
# Rule: ('juice', 'dinner rolls') ==> ('vegetables',) , 0.861
# Rule: ('paper towels', 'eggs') ==> ('vegetables',) , 0.863
# Rule: ('aluminum foil', 'eggs') ==> ('vegetables',) , 0.863
# Rule: ('laundry detergent', 'yogurt') ==> ('vegetables',) , 0.865
# Rule: ('pork', 'lunch meat') ==> ('vegetables',) , 0.865
# Rule: ('soda', 'lunch meat') ==> ('vegetables',) , 0.866
# Rule: ('juice', 'eggs') ==> ('vegetables',) , 0.866
# Rule: ('sandwich bags', 'eggs') ==> ('vegetables',) , 0.866
# Rule: ('juice', 'butter') ==> ('vegetables',) , 0.866
# Rule: ('juice', 'laundry detergent') ==> ('vegetables',) , 0.866
# Rule: ('laundry detergent', 'shampoo') ==> ('vegetables',) , 0.867
# Rule: ('yogurt', 'milk') ==> ('vegetables',) , 0.875
# Rule: ('sugar', 'flour') ==> ('vegetables',) , 0.875
# Rule: ('sugar', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.877
# Rule: ('cheeses', 'eggs') ==> ('vegetables',) , 0.879
# Rule: ('dishwashing liquid/detergent', 'yogurt') ==> ('vegetables',) , 0.879
# Rule: ('eggs', 'lunch meat') ==> ('vegetables',) , 0.881
# Rule: ('eggs', 'yogurt') ==> ('vegetables',) , 0.883
# Rule: ('sandwich loaves', 'eggs') ==> ('vegetables',) , 0.886

# %%
print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #') 
print ('Case 2 (minimum support=0.1 and minimum confidence=0.8)')

print ('Case 2 Reasoning:')
print('Here is the maximum value possible for confidence is evaluated, keeping the support minimum.')
print('It looks like it slightly affected the number of items. However, I am not sure here.')
print('The increased value of confidence reduced the number of rules derived.')
print('If I increase the value from 0.8, it derives no rules.')
print ('\nCase 2 Output:') 
# %run apriori.py -f DATASET.csv -s 0.1 -c 0.8
# Out:
# # # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #
# Case 2 (minimum support=0.1 and minimum confidence=0.8)
# Case 2 Reasoning:
# Here is the maximum value possible for confidence is evaluated, keeping the support minimum.
# It looks like it slightly affected the number of items. However, I am not sure here.
# The increased value of confidence reduced the number of rules derived.
# If I increase the value from 0.8, it derives no rules.
#
# Case 2 Output:
#
# ------------ITEMS-----------------
# item: ('vegetables', 'butter', 'ketchup') , 0.100
# item: ('beef', 'vegetables', 'individual meals') , 0.100
# item: ('vegetables', 'aluminum foil', 'pork') , 0.100
# item: ('vegetables', 'flour', 'shampoo') , 0.100
# item: ('vegetables', 'dishwashing liquid/detergent', 'ketchup') , 0.100
# item: ('vegetables', 'butter', 'waffles') , 0.100
# item: ('vegetables', 'sandwich bags', 'flour') , 0.100
# item: ('flour', 'sandwich loaves', 'vegetables') , 0.100
# item: ('beef', 'sandwich loaves', 'vegetables') , 0.100
# item: ('vegetables', 'all- purpose', 'shampoo') , 0.100
# item: ('sandwich loaves', 'fruits', 'vegetables') , 0.100
# item: ('vegetables', 'fruits', 'coffee/tea') , 0.100
# item: ('vegetables', 'mixes', 'fruits') , 0.100
# item: ('juice', 'sandwich bags', 'vegetables') , 0.100
# item: ('sandwich loaves', 'mixes', 'vegetables') , 0.100
# item: ('vegetables', 'sugar', 'fruits') , 0.100
# item: ('pork', 'dinner rolls', 'vegetables') , 0.100
# item: ('flour', 'vegetables', 'all- purpose') , 0.100
# item: ('vegetables', 'dishwashing liquid/detergent', 'shampoo') , 0.100
# item: ('vegetables', 'butter', 'sandwich bags') , 0.101
# item: ('vegetables', 'toilet paper', 'butter') , 0.101
# item: ('spaghetti sauce', 'vegetables', 'individual meals') , 0.101
# item: ('spaghetti sauce', 'vegetables', 'ice cream') , 0.101
# item: ('vegetables', 'cereals', 'butter') , 0.101
# item: ('vegetables', 'pork', 'ketchup') , 0.101
# item: ('hand soap', 'vegetables', 'eggs') , 0.101
# item: ('vegetables', 'all- purpose', 'pasta') , 0.101
# item: ('beef', 'vegetables', 'soda') , 0.101
# item: ('vegetables', 'all- purpose', 'coffee/tea') , 0.101
# item: ('spaghetti sauce', 'vegetables', 'ketchup') , 0.101
# item: ('vegetables', 'bagels', 'all- purpose') , 0.101
# item: ('sandwich bags', 'vegetables', 'pasta') , 0.101
# item: ('vegetables', 'butter', 'ice cream') , 0.101
# item: ('juice', 'vegetables', 'cheeses') , 0.101
# item: ('vegetables', 'tortillas', 'paper towels') , 0.101
# item: ('laundry detergent', 'vegetables', 'fruits') , 0.102
# item: ('vegetables', 'sugar', 'paper towels') , 0.102
# item: ('vegetables', 'milk', 'shampoo') , 0.102
# item: ('vegetables', 'soda', 'mixes') , 0.102
# item: ('vegetables', 'tortillas', 'sugar') , 0.102
# item: ('hand soap', 'vegetables', 'ketchup') , 0.102
# item: ('vegetables', 'cereals', 'ketchup') , 0.102
# item: ('vegetables', 'dishwashing liquid/detergent', 'pasta') , 0.102
# item: ('vegetables', 'sugar', 'individual meals') , 0.102
# item: ('sandwich bags', 'vegetables', 'coffee/tea') , 0.102
# item: ('sandwich bags', 'vegetables', 'ice cream') , 0.102
# item: ('sandwich bags', 'vegetables', 'aluminum foil') , 0.102
# item: ('beef', 'vegetables', 'waffles') , 0.102
# item: ('vegetables', 'cereals', 'flour') , 0.102
# item: ('individual meals', 'vegetables', 'coffee/tea') , 0.102
# item: ('vegetables', 'butter', 'coffee/tea') , 0.102
# item: ('pasta', 'vegetables', 'milk') , 0.102
# item: ('beef', 'bagels', 'vegetables') , 0.102
# item: ('vegetables', 'paper towels', 'bagels') , 0.102
# item: ('vegetables', 'dishwashing liquid/detergent', 'individual meals') , 0.102
# item: ('bagels', 'fruits', 'vegetables') , 0.102
# item: ('sandwich bags', 'vegetables', 'fruits') , 0.103
# item: ('soap', 'vegetables', 'fruits') , 0.103
# item: ('vegetables', 'paper towels', 'flour') , 0.103
# item: ('vegetables', 'toilet paper', 'ice cream') , 0.103
# item: ('vegetables', 'mixes', 'all- purpose') , 0.103
# item: ('vegetables', 'toilet paper', 'dishwashing liquid/detergent') , 0.103
# item: ('vegetables', 'soda', 'toilet paper') , 0.103
# item: ('sandwich loaves', 'vegetables', 'lunch meat') , 0.103
# item: ('vegetables', 'toilet paper', 'sugar') , 0.103
# item: ('vegetables', 'all- purpose', 'ketchup') , 0.103
# item: ('vegetables', 'sugar', 'milk') , 0.103
# item: ('hand soap', 'vegetables', 'individual meals') , 0.103
# item: ('sandwich bags', 'vegetables', 'dishwashing liquid/detergent') , 0.103
# item: ('laundry detergent', 'vegetables', 'sugar') , 0.103
# item: ('vegetables', 'butter', 'paper towels') , 0.103
# item: ('beef', 'vegetables', 'dishwashing liquid/detergent') , 0.103
# item: ('sandwich bags', 'vegetables', 'bagels') , 0.103
# item: ('vegetables', 'paper towels', 'individual meals') , 0.103
# item: ('vegetables', 'sugar', 'shampoo') , 0.103
# item: ('vegetables', 'tortillas', 'yogurt') , 0.103
# item: ('spaghetti sauce', 'vegetables', 'butter') , 0.103
# item: ('vegetables', 'sugar', 'coffee/tea') , 0.103
# item: ('sandwich loaves', 'vegetables', 'eggs') , 0.103
# item: ('vegetables', 'flour', 'waffles') , 0.103
# item: ('vegetables', 'fruits', 'ketchup') , 0.103
# item: ('vegetables', 'tortillas', 'eggs') , 0.103
# item: ('beef', 'vegetables', 'paper towels') , 0.103
# item: ('vegetables', 'cereals', 'sandwich bags') , 0.103
# item: ('vegetables', 'pork', 'waffles') , 0.104
# item: ('spaghetti sauce', 'sandwich loaves', 'vegetables') , 0.104
# item: ('vegetables', 'mixes', 'waffles') , 0.104
# item: ('vegetables', 'mixes', 'pork') , 0.104
# item: ('beef', 'toilet paper', 'vegetables') , 0.104
# item: ('vegetables', 'tortillas', 'lunch meat') , 0.104
# item: ('vegetables', 'bagels', 'pork') , 0.104
# item: ('vegetables', 'bagels', 'milk') , 0.104
# item: ('vegetables', 'mixes', 'bagels') , 0.104
# item: ('vegetables', 'mixes', 'individual meals') , 0.104
# item: ('vegetables', 'ice cream', 'milk') , 0.104
# item: ('vegetables', 'bagels', 'coffee/tea') , 0.104
# item: ('vegetables', 'ice cream', 'coffee/tea') , 0.104
# item: ('vegetables', 'sugar', 'soap') , 0.104
# item: ('sandwich bags', 'vegetables', 'individual meals') , 0.104
# item: ('vegetables', 'mixes', 'coffee/tea') , 0.104
# item: ('beef', 'cheeses', 'vegetables') , 0.104
# item: ('juice', 'sandwich loaves', 'vegetables') , 0.104
# item: ('vegetables', 'flour', 'milk') , 0.104
# item: ('soap', 'vegetables', 'bagels') , 0.104
# item: ('vegetables', 'ketchup', 'shampoo') , 0.104
# item: ('vegetables', 'flour', 'lunch meat') , 0.104
# item: ('sandwich loaves', 'paper towels', 'vegetables') , 0.104
# item: ('beef', 'dinner rolls', 'vegetables') , 0.104
# item: ('vegetables', 'toilet paper', 'all- purpose') , 0.104
# item: ('sandwich loaves', 'butter', 'vegetables') , 0.104
# item: ('pork', 'vegetables', 'all- purpose') , 0.104
# item: ('vegetables', 'cereals', 'sugar') , 0.104
# item: ('spaghetti sauce', 'vegetables', 'paper towels') , 0.104
# item: ('dinner rolls', 'sandwich bags', 'vegetables') , 0.104
# item: ('vegetables', 'tortillas', 'coffee/tea') , 0.104
# item: ('vegetables', 'soda', 'all- purpose') , 0.104
# item: ('vegetables', 'butter', 'lunch meat') , 0.104
# item: ('hand soap', 'vegetables', 'lunch meat') , 0.104
# item: ('vegetables', 'fruits', 'yogurt') , 0.104
# item: ('vegetables', 'cheeses', 'milk') , 0.104
# item: ('vegetables', 'ketchup', 'pasta') , 0.104
# item: ('sandwich loaves', 'sugar', 'vegetables') , 0.104
# item: ('vegetables', 'bagels', 'shampoo') , 0.104
# item: ('vegetables', 'paper towels', 'fruits') , 0.104
# item: ('beef', 'vegetables', 'milk') , 0.104
# item: ('sandwich loaves', 'cereals', 'vegetables') , 0.104
# item: ('vegetables', 'lunch meat', 'ketchup') , 0.104
# item: ('vegetables', 'butter', 'shampoo') , 0.104
# item: ('vegetables', 'cheeses', 'all- purpose') , 0.104
# item: ('vegetables', 'toilet paper', 'shampoo') , 0.104
# item: ('shampoo', 'vegetables', 'individual meals') , 0.104
# item: ('vegetables', 'cereals', 'all- purpose') , 0.104
# item: ('vegetables', 'cereals', 'bagels') , 0.104
# item: ('juice', 'vegetables', 'milk') , 0.104
# item: ('vegetables', 'soda', 'bagels') , 0.104
# item: ('sandwich loaves', 'vegetables', 'waffles') , 0.104
# item: ('vegetables', 'butter', 'aluminum foil') , 0.104
# item: ('vegetables', 'fruits', 'all- purpose') , 0.104
# item: ('beef', 'butter') , 0.105
# item: ('vegetables', 'butter', 'cheeses') , 0.105
# item: ('laundry detergent', 'vegetables', 'flour') , 0.105
# item: ('vegetables', 'ice cream', 'shampoo') , 0.105
# item: ('coffee/tea', 'vegetables', 'shampoo') , 0.105
# item: ('beef', 'vegetables', 'ketchup') , 0.105
# item: ('vegetables', 'sugar', 'aluminum foil') , 0.105
# item: ('sandwich loaves', 'vegetables', 'ketchup') , 0.105
# item: ('pork', 'vegetables', 'eggs') , 0.105
# item: ('vegetables', 'soda', 'sandwich bags') , 0.105
# item: ('vegetables', 'soda', 'ketchup') , 0.105
# item: ('vegetables', 'fruits', 'aluminum foil') , 0.105
# item: ('spaghetti sauce', 'vegetables', 'mixes') , 0.105
# item: ('vegetables', 'tortillas', 'mixes') , 0.105
# item: ('vegetables', 'butter', 'soap') , 0.106
# item: ('dinner rolls', 'tortillas', 'vegetables') , 0.106
# item: ('flour', 'vegetables', 'eggs') , 0.106
# item: ('vegetables', 'toilet paper', 'individual meals') , 0.106
# item: ('vegetables', 'ice cream', 'ketchup') , 0.106
# item: ('sandwich loaves', 'soap', 'vegetables') , 0.106
# item: ('juice', 'vegetables', 'pork') , 0.106
# item: ('vegetables', 'mixes', 'soap') , 0.106
# item: ('vegetables', 'cheeses', 'dishwashing liquid/detergent') , 0.106
# item: ('sandwich bags', 'vegetables', 'lunch meat') , 0.106
# item: ('vegetables', 'ketchup', 'milk') , 0.106
# item: ('vegetables', 'cereals', 'soda') , 0.106
# item: ('vegetables', 'pork', 'coffee/tea') , 0.106
# item: ('juice', 'vegetables', 'dishwashing liquid/detergent') , 0.106
# item: ('laundry detergent', 'vegetables', 'coffee/tea') , 0.106
# item: ('dinner rolls', 'butter', 'vegetables') , 0.106
# item: ('laundry detergent', 'vegetables', 'pasta') , 0.106
# item: ('beef', 'vegetables', 'shampoo') , 0.106
# item: ('sandwich loaves', 'vegetables', 'coffee/tea') , 0.106
# item: ('hand soap', 'dinner rolls', 'vegetables') , 0.106
# item: ('vegetables', 'fruits', 'cheeses') , 0.106
# item: ('vegetables', 'bagels', 'yogurt') , 0.106
# item: ('hand soap', 'vegetables', 'poultry') , 0.106
# item: ('vegetables', 'fruits', 'milk') , 0.106
# item: ('vegetables', 'toilet paper', 'paper towels') , 0.107
# item: ('milk', 'vegetables', 'coffee/tea') , 0.107
# item: ('laundry detergent', 'vegetables', 'individual meals') , 0.107
# item: ('sandwich bags', 'vegetables', 'milk') , 0.107
# item: ('vegetables', 'bagels', 'ketchup') , 0.107
# item: ('sandwich loaves', 'aluminum foil', 'vegetables') , 0.107
# item: ('laundry detergent', 'vegetables', 'bagels') , 0.107
# item: ('vegetables', 'soap', 'flour') , 0.107
# item: ('juice', 'vegetables', 'all- purpose') , 0.107
# item: ('vegetables', 'paper towels', 'waffles') , 0.107
# item: ('vegetables', 'sugar', 'eggs') , 0.107
# item: ('juice', 'beef', 'vegetables') , 0.107
# item: ('juice', 'vegetables', 'cereals') , 0.107
# item: ('laundry detergent', 'vegetables', 'toilet paper') , 0.107
# item: ('sandwich loaves', 'soda', 'vegetables') , 0.107
# item: ('spaghetti sauce', 'vegetables', 'cheeses') , 0.107
# item: ('beef', 'sugar', 'vegetables') , 0.107
# item: ('vegetables', 'pork', 'lunch meat') , 0.107
# item: ('vegetables', 'aluminum foil', 'lunch meat') , 0.107
# item: ('vegetables', 'soda', 'coffee/tea') , 0.107
# item: ('coffee/tea', 'vegetables', 'pasta') , 0.107
# item: ('beef', 'soap', 'vegetables') , 0.107
# item: ('vegetables', 'aluminum foil', 'pasta') , 0.107
# item: ('soap', 'vegetables', 'aluminum foil') , 0.107
# item: ('dinner rolls', 'vegetables', 'individual meals') , 0.107
# item: ('vegetables', 'bagels', 'waffles') , 0.107
# item: ('vegetables', 'toilet paper', 'dinner rolls') , 0.107
# item: ('vegetables', 'all- purpose', 'milk') , 0.107
# item: ('vegetables', 'pork', 'yogurt') , 0.107
# item: ('juice', 'vegetables', 'soda') , 0.107
# item: ('vegetables', 'fruits', 'ice cream') , 0.107
# item: ('dinner rolls', 'vegetables', 'all- purpose') , 0.107
# item: ('spaghetti sauce', 'vegetables', 'pork') , 0.107
# item: ('vegetables', 'toilet paper', 'ketchup') , 0.108
# item: ('laundry detergent', 'vegetables', 'paper towels') , 0.108
# item: ('vegetables', 'toilet paper', 'cheeses') , 0.108
# item: ('sandwich bags', 'vegetables', 'ketchup') , 0.108
# item: ('vegetables', 'paper towels', 'pasta') , 0.108
# item: ('vegetables', 'flour', 'coffee/tea') , 0.108
# item: ('vegetables', 'mixes', 'cheeses') , 0.108
# item: ('vegetables', 'fruits', 'waffles') , 0.108
# item: ('vegetables', 'aluminum foil', 'individual meals') , 0.108
# item: ('vegetables', 'mixes', 'shampoo') , 0.108
# item: ('vegetables', 'sugar', 'cheeses') , 0.108
# item: ('sandwich bags', 'vegetables', 'shampoo') , 0.108
# item: ('sandwich loaves', 'dinner rolls', 'vegetables') , 0.108
# item: ('dinner rolls', 'vegetables', 'coffee/tea') , 0.108
# item: ('juice', 'vegetables', 'mixes') , 0.108
# item: ('vegetables', 'cereals', 'individual meals') , 0.108
# item: ('vegetables', 'sandwich bags', 'eggs') , 0.108
# item: ('vegetables', 'paper towels', 'cheeses') , 0.108
# item: ('vegetables', 'soap', 'yogurt') , 0.108
# item: ('dinner rolls', 'vegetables', 'ice cream') , 0.108
# item: ('juice', 'vegetables', 'individual meals') , 0.108
# item: ('juice', 'vegetables', 'butter') , 0.108
# item: ('hand soap', 'butter') , 0.109
# item: ('dinner rolls', 'soap', 'vegetables') , 0.109
# item: ('beef', 'vegetables', 'lunch meat') , 0.109
# item: ('vegetables', 'paper towels', 'dishwashing liquid/detergent') , 0.109
# item: ('vegetables', 'butter', 'mixes') , 0.109
# item: ('vegetables', 'toilet paper', 'waffles') , 0.109
# item: ('vegetables', 'toilet paper', 'mixes') , 0.109
# item: ('vegetables', 'soda', 'sugar') , 0.109
# item: ('vegetables', 'all- purpose', 'dishwashing liquid/detergent') , 0.109
# item: ('vegetables', 'soap', 'dishwashing liquid/detergent') , 0.109
# item: ('vegetables', 'soap', 'shampoo') , 0.109
# item: ('vegetables', 'bagels', 'cheeses') , 0.109
# item: ('poultry', 'vegetables', 'fruits') , 0.109
# item: ('vegetables', 'cheeses', 'shampoo') , 0.109
# item: ('vegetables', 'eggs', 'shampoo') , 0.109
# item: ('vegetables', 'soda', 'shampoo') , 0.109
# item: ('vegetables', 'ice cream', 'yogurt') , 0.109
# item: ('vegetables', 'lunch meat', 'shampoo') , 0.109
# item: ('vegetables', 'mixes', 'lunch meat') , 0.109
# item: ('vegetables', 'toilet paper', 'yogurt') , 0.109
# item: ('vegetables', 'ice cream', 'pasta') , 0.109
# item: ('dinner rolls', 'vegetables', 'milk') , 0.109
# item: ('vegetables', 'lunch meat', 'all- purpose') , 0.109
# item: ('vegetables', 'toilet paper', 'bagels') , 0.109
# item: ('dinner rolls', 'bagels', 'vegetables') , 0.110
# item: ('shampoo', 'vegetables', 'yogurt') , 0.110
# item: ('spaghetti sauce', 'vegetables', 'aluminum foil') , 0.110
# item: ('laundry detergent', 'vegetables', 'spaghetti sauce') , 0.110
# item: ('vegetables', 'soap', 'coffee/tea') , 0.110
# item: ('vegetables', 'soap', 'ice cream') , 0.110
# item: ('vegetables', 'bagels', 'ice cream') , 0.110
# item: ('vegetables', 'waffles', 'pasta') , 0.110
# item: ('vegetables', 'aluminum foil', 'all- purpose') , 0.110
# item: ('vegetables', 'paper towels', 'shampoo') , 0.110
# item: ('vegetables', 'cereals', 'ice cream') , 0.110
# item: ('vegetables', 'toilet paper', 'lunch meat') , 0.110
# item: ('vegetables', 'paper towels', 'coffee/tea') , 0.110
# item: ('vegetables', 'toilet paper', 'coffee/tea') , 0.110
# item: ('vegetables', 'dishwashing liquid/detergent', 'coffee/tea') , 0.110
# item: ('spaghetti sauce', 'vegetables', 'yogurt') , 0.110
# item: ('sandwich loaves', 'pork') , 0.111
# item: ('fruits', 'pork') , 0.111
# item: ('bagels', 'flour') , 0.111
# item: ('vegetables', 'soda', 'flour') , 0.111
# item: ('vegetables', 'toilet paper', 'aluminum foil') , 0.111
# item: ('vegetables', 'eggs', 'individual meals') , 0.111
# item: ('spaghetti sauce', 'vegetables', 'cereals') , 0.111
# item: ('vegetables', 'fruits', 'eggs') , 0.111
# item: ('vegetables', 'soap', 'milk') , 0.111
# item: ('poultry', 'vegetables', 'waffles') , 0.111
# item: ('vegetables', 'ice cream', 'individual meals') , 0.111
# item: ('vegetables', 'mixes', 'milk') , 0.111
# item: ('vegetables', 'cereals', 'waffles') , 0.111
# item: ('spaghetti sauce', 'vegetables', 'pasta') , 0.111
# item: ('poultry', 'vegetables', 'tortillas') , 0.111
# item: ('beef', 'aluminum foil', 'vegetables') , 0.111
# item: ('vegetables', 'aluminum foil', 'coffee/tea') , 0.111
# item: ('laundry detergent', 'vegetables', 'butter') , 0.111
# item: ('laundry detergent', 'vegetables', 'lunch meat') , 0.111
# item: ('vegetables', 'toilet paper', 'milk') , 0.111
# item: ('vegetables', 'soap', 'pasta') , 0.111
# item: ('vegetables', 'paper towels', 'sandwich bags') , 0.111
# item: ('dinner rolls', 'vegetables', 'pasta') , 0.111
# item: ('vegetables', 'ketchup', 'yogurt') , 0.111
# item: ('vegetables', 'eggs', 'ice cream') , 0.111
# item: ('vegetables', 'soap', 'all- purpose') , 0.111
# item: ('vegetables', 'sugar', 'flour') , 0.111
# item: ('vegetables', 'all- purpose', 'ice cream') , 0.111
# item: ('vegetables', 'mixes', 'flour') , 0.111
# item: ('vegetables', 'mixes', 'yogurt') , 0.111
# item: ('juice', 'vegetables', 'lunch meat') , 0.111
# item: ('hand soap', 'flour') , 0.111
# item: ('sandwich bags', 'sugar') , 0.111
# item: ('sandwich loaves', 'dishwashing liquid/detergent') , 0.111
# item: ('hand soap', 'bagels') , 0.111
# item: ('hand soap', 'all- purpose') , 0.111
# item: ('butter', 'pasta') , 0.111
# item: ('juice', 'vegetables', 'toilet paper') , 0.111
# item: ('beef', 'vegetables', 'fruits') , 0.111
# item: ('vegetables', 'soda', 'paper towels') , 0.111
# item: ('vegetables', 'mixes', 'eggs') , 0.111
# item: ('vegetables', 'lunch meat', 'milk') , 0.111
# item: ('vegetables', 'paper towels', 'yogurt') , 0.111
# item: ('vegetables', 'paper towels', 'milk') , 0.111
# item: ('vegetables', 'fruits', 'lunch meat') , 0.111
# item: ('poultry', 'vegetables', 'beef') , 0.111
# item: ('vegetables', 'cereals', 'shampoo') , 0.111
# item: ('laundry detergent', 'vegetables', 'ice cream') , 0.111
# item: ('sandwich loaves', 'cheeses', 'vegetables') , 0.111
# item: ('beef', 'vegetables', 'eggs') , 0.111
# item: ('juice', 'vegetables', 'coffee/tea') , 0.111
# item: ('dinner rolls', 'vegetables', 'lunch meat') , 0.111
# item: ('vegetables', 'bagels', 'lunch meat') , 0.111
# item: ('spaghetti sauce', 'vegetables', 'bagels') , 0.111
# item: ('vegetables', 'cereals', 'fruits') , 0.111
# item: ('shampoo', 'vegetables', 'waffles') , 0.111
# item: ('vegetables', 'dishwashing liquid/detergent', 'ice cream') , 0.111
# item: ('juice', 'vegetables', 'soap') , 0.111
# item: ('vegetables', 'sugar', 'ice cream') , 0.111
# item: ('vegetables', 'paper towels', 'soap') , 0.111
# item: ('dinner rolls', 'vegetables', 'ketchup') , 0.111
# item: ('vegetables', 'lunch meat', 'coffee/tea') , 0.111
# item: ('vegetables', 'cheeses', 'pasta') , 0.111
# item: ('beef', 'vegetables', 'cereals') , 0.111
# item: ('vegetables', 'cereals', 'pasta') , 0.111
# item: ('hand soap', 'pork') , 0.112
# item: ('hand soap', 'soap') , 0.112
# item: ('vegetables', 'toilet paper', 'soap') , 0.112
# item: ('poultry', 'vegetables', 'butter') , 0.112
# item: ('vegetables', 'cereals', 'milk') , 0.112
# item: ('dinner rolls', 'vegetables', 'dishwashing liquid/detergent') , 0.112
# item: ('flour', 'dinner rolls', 'vegetables') , 0.112
# item: ('vegetables', 'soda', 'dishwashing liquid/detergent') , 0.112
# item: ('spaghetti sauce', 'vegetables', 'lunch meat') , 0.112
# item: ('vegetables', 'aluminum foil', 'dishwashing liquid/detergent') , 0.112
# item: ('spaghetti sauce', 'vegetables', 'soap') , 0.112
# item: ('vegetables', 'aluminum foil', 'flour') , 0.112
# item: ('vegetables', 'bagels', 'individual meals') , 0.112
# item: ('vegetables', 'soap', 'individual meals') , 0.112
# item: ('sandwich bags', 'soap', 'vegetables') , 0.112
# item: ('vegetables', 'cereals', 'dinner rolls') , 0.112
# item: ('vegetables', 'cheeses', 'lunch meat') , 0.112
# item: ('vegetables', 'mixes', 'dinner rolls') , 0.112
# item: ('juice', 'vegetables', 'ice cream') , 0.112
# item: ('poultry', 'vegetables', 'sandwich bags') , 0.112
# item: ('poultry', 'vegetables', 'flour') , 0.112
# item: ('vegetables', 'sugar', 'dishwashing liquid/detergent') , 0.112
# item: ('vegetables', 'paper towels', 'ice cream') , 0.112
# item: ('vegetables', 'soda', 'cheeses') , 0.112
# item: ('vegetables', 'aluminum foil', 'ketchup') , 0.112
# item: ('sandwich loaves', 'vegetables', 'yogurt') , 0.112
# item: ('vegetables', 'cereals', 'soap') , 0.112
# item: ('tortillas', 'shampoo') , 0.113
# item: ('hand soap', 'toilet paper') , 0.113
# item: ('tortillas', 'fruits') , 0.113
# item: ('laundry detergent', 'vegetables', 'mixes') , 0.113
# item: ('vegetables', 'yogurt', 'individual meals') , 0.113
# item: ('coffee/tea', 'vegetables', 'yogurt') , 0.113
# item: ('vegetables', 'cheeses', 'flour') , 0.113
# item: ('sandwich loaves', 'vegetables', 'individual meals') , 0.113
# item: ('dinner rolls', 'paper towels', 'vegetables') , 0.113
# item: ('vegetables', 'butter', 'eggs') , 0.113
# item: ('vegetables', 'cheeses', 'individual meals') , 0.113
# item: ('beef', 'vegetables', 'yogurt') , 0.113
# item: ('vegetables', 'all- purpose', 'waffles') , 0.113
# item: ('laundry detergent', 'vegetables', 'dishwashing liquid/detergent') , 0.113
# item: ('vegetables', 'soda', 'lunch meat') , 0.113
# item: ('vegetables', 'flour', 'ketchup') , 0.113
# item: ('poultry', 'vegetables', 'pasta') , 0.113
# item: ('sandwich bags', 'vegetables', 'yogurt') , 0.113
# item: ('sandwich loaves', 'vegetables', 'shampoo') , 0.113
# item: ('laundry detergent', 'sandwich loaves') , 0.114
# item: ('hand soap', 'paper towels') , 0.114
# item: ('hand soap', 'fruits') , 0.114
# item: ('hand soap', 'aluminum foil') , 0.114
# item: ('butter', 'yogurt') , 0.114
# item: ('hand soap', 'sandwich loaves') , 0.114
# item: ('spaghetti sauce', 'vegetables', 'soda') , 0.114
# item: ('vegetables', 'cereals', 'cheeses') , 0.114
# item: ('laundry detergent', 'vegetables', 'soap') , 0.114
# item: ('vegetables', 'lunch meat', 'yogurt') , 0.114
# item: ('vegetables', 'fruits', 'dishwashing liquid/detergent') , 0.114
# item: ('vegetables', 'aluminum foil', 'milk') , 0.114
# item: ('vegetables', 'sugar', 'yogurt') , 0.114
# item: ('vegetables', 'aluminum foil', 'shampoo') , 0.114
# item: ('juice', 'vegetables', 'bagels') , 0.114
# item: ('vegetables', 'ketchup', 'coffee/tea') , 0.114
# item: ('dinner rolls', 'vegetables', 'shampoo') , 0.114
# item: ('sandwich loaves', 'vegetables', 'ice cream') , 0.114
# item: ('vegetables', 'cereals', 'toilet paper') , 0.114
# item: ('beef', 'vegetables', 'ice cream') , 0.114
# item: ('vegetables', 'yogurt', 'pasta') , 0.114
# item: ('individual meals', 'vegetables', 'waffles') , 0.114
# item: ('poultry', 'vegetables', 'bagels') , 0.114
# item: ('vegetables', 'soda', 'ice cream') , 0.114
# item: ('vegetables', 'waffles', 'ice cream') , 0.114
# item: ('laundry detergent', 'vegetables', 'soda') , 0.114
# item: ('hand soap', 'tortillas') , 0.115
# item: ('hand soap', 'sugar') , 0.115
# item: ('spaghetti sauce', 'tortillas') , 0.115
# item: ('sugar', 'pork') , 0.115
# item: ('sandwich loaves', 'milk') , 0.115
# item: ('laundry detergent', 'vegetables', 'aluminum foil') , 0.115
# item: ('poultry', 'vegetables', 'pork') , 0.115
# item: ('vegetables', 'dishwashing liquid/detergent', 'yogurt') , 0.115
# item: ('vegetables', 'toilet paper', 'eggs') , 0.115
# item: ('juice', 'vegetables', 'paper towels') , 0.115
# item: ('vegetables', 'eggs', 'coffee/tea') , 0.115
# item: ('laundry detergent', 'vegetables', 'milk') , 0.115
# item: ('paper towels', 'vegetables', 'mixes') , 0.115
# item: ('vegetables', 'dishwashing liquid/detergent', 'milk') , 0.115
# item: ('vegetables', 'cereals', 'aluminum foil') , 0.115
# item: ('dinner rolls', 'sugar', 'vegetables') , 0.115
# item: ('sandwich loaves', 'eggs') , 0.116
# item: ('lunch meat', 'pasta') , 0.116
# item: ('sandwich loaves', 'pasta') , 0.116
# item: ('spaghetti sauce', 'shampoo') , 0.116
# item: ('laundry detergent', 'vegetables', 'eggs') , 0.116
# item: ('vegetables', 'soda', 'milk') , 0.116
# item: ('vegetables', 'mixes', 'ketchup') , 0.116
# item: ('juice', 'vegetables', 'waffles') , 0.116
# item: ('sandwich bags', 'vegetables', 'waffles') , 0.116
# item: ('dinner rolls', 'aluminum foil', 'vegetables') , 0.116
# item: ('vegetables', 'aluminum foil', 'eggs') , 0.116
# item: ('vegetables', 'paper towels', 'ketchup') , 0.116
# item: ('laundry detergent', 'vegetables', 'ketchup') , 0.116
# item: ('butter', 'flour') , 0.117
# item: ('hand soap', 'sandwich bags') , 0.117
# item: ('juice', 'flour') , 0.117
# item: ('pork', 'pasta') , 0.117
# item: ('vegetables', 'eggs', 'lunch meat') , 0.117
# item: ('vegetables', 'paper towels', 'all- purpose') , 0.117
# item: ('spaghetti sauce', 'vegetables', 'eggs') , 0.117
# item: ('vegetables', 'cheeses', 'ketchup') , 0.117
# item: ('vegetables', 'ketchup', 'waffles') , 0.117
# item: ('laundry detergent', 'vegetables', 'cheeses') , 0.117
# item: ('vegetables', 'cereals', 'coffee/tea') , 0.117
# item: ('vegetables', 'cereals', 'mixes') , 0.117
# item: ('vegetables', 'cereals', 'paper towels') , 0.117
# item: ('vegetables', 'sugar', 'waffles') , 0.117
# item: ('laundry detergent', 'vegetables', 'all- purpose') , 0.117
# item: ('vegetables', 'bagels', 'dishwashing liquid/detergent') , 0.117
# item: ('poultry', 'vegetables', 'ketchup') , 0.117
# item: ('laundry detergent', 'vegetables', 'waffles') , 0.117
# item: ('spaghetti sauce', 'dishwashing liquid/detergent') , 0.118
# item: ('tortillas', 'all- purpose') , 0.118
# item: ('spaghetti sauce', 'flour') , 0.118
# item: ('butter', 'sugar') , 0.118
# item: ('butter', 'fruits') , 0.118
# item: ('toilet paper', 'fruits') , 0.118
# item: ('spaghetti sauce', 'sugar') , 0.118
# item: ('hand soap', 'yogurt') , 0.118
# item: ('hand soap', 'spaghetti sauce') , 0.118
# item: ('beef', 'flour') , 0.118
# item: ('vegetables', 'sugar', 'lunch meat') , 0.118
# item: ('vegetables', 'soap', 'ketchup') , 0.118
# item: ('vegetables', 'soda', 'waffles') , 0.118
# item: ('juice', 'vegetables', 'ketchup') , 0.118
# item: ('vegetables', 'waffles', 'coffee/tea') , 0.118
# item: ('poultry', 'vegetables', 'toilet paper') , 0.118
# item: ('laundry detergent', 'vegetables', 'yogurt') , 0.118
# item: ('vegetables', 'lunch meat', 'ice cream') , 0.118
# item: ('vegetables', 'flour', 'yogurt') , 0.118
# item: ('vegetables', 'dishwashing liquid/detergent', 'waffles') , 0.118
# item: ('vegetables', 'cheeses', 'aluminum foil') , 0.118
# item: ('vegetables', 'soda', 'aluminum foil') , 0.118
# item: ('vegetables', 'soda', 'pasta') , 0.118
# item: ('sugar', 'ketchup') , 0.118
# item: ('hand soap', 'soda') , 0.118
# item: ('butter', 'pork') , 0.118
# item: ('hand soap', 'shampoo') , 0.118
# item: ('pork', 'milk') , 0.118
# item: ('hand soap', 'pasta') , 0.118
# item: ('spaghetti sauce', 'sandwich bags') , 0.118
# item: ('tortillas', 'flour') , 0.118
# item: ('all- purpose', 'individual meals') , 0.118
# item: ('hand soap', 'dishwashing liquid/detergent') , 0.118
# item: ('laundry detergent', 'sandwich bags', 'vegetables') , 0.118
# item: ('vegetables', 'mixes', 'dishwashing liquid/detergent') , 0.118
# item: ('vegetables', 'all- purpose', 'eggs') , 0.118
# item: ('dinner rolls', 'vegetables', 'yogurt') , 0.118
# item: ('soap', 'vegetables', 'cheeses') , 0.118
# item: ('vegetables', 'soap', 'lunch meat') , 0.118
# item: ('vegetables', 'cheeses', 'coffee/tea') , 0.118
# item: ('spaghetti sauce', 'vegetables', 'waffles') , 0.118
# item: ('vegetables', 'paper towels', 'aluminum foil') , 0.118
# item: ('vegetables', 'dishwashing liquid/detergent', 'lunch meat') , 0.118
# item: ('spaghetti sauce', 'dinner rolls', 'vegetables') , 0.118
# item: ('tortillas', 'pasta') , 0.119
# item: ('juice', 'fruits') , 0.119
# item: ('tortillas', 'cheeses') , 0.119
# item: ('pork', 'ice cream') , 0.119
# item: ('sandwich loaves', 'tortillas') , 0.119
# item: ('hand soap', 'juice') , 0.119
# item: ('sandwich loaves', 'flour') , 0.119
# item: ('vegetables', 'aluminum foil', 'ice cream') , 0.119
# item: ('vegetables', 'eggs', 'dishwashing liquid/detergent') , 0.119
# item: ('juice', 'dinner rolls', 'vegetables') , 0.119
# item: ('vegetables', 'cereals', 'eggs') , 0.119
# item: ('vegetables', 'all- purpose', 'yogurt') , 0.119
# item: ('vegetables', 'paper towels', 'lunch meat') , 0.119
# item: ('vegetables', 'lunch meat', 'individual meals') , 0.119
# item: ('spaghetti sauce', 'vegetables', 'poultry') , 0.119
# item: ('poultry', 'vegetables', 'paper towels') , 0.119
# item: ('juice', 'vegetables', 'laundry detergent') , 0.119
# item: ('hand soap', 'cereals') , 0.120
# item: ('butter', 'milk') , 0.120
# item: ('pasta', 'individual meals') , 0.120
# item: ('hand soap', 'eggs') , 0.120
# item: ('vegetables', 'cereals', 'dishwashing liquid/detergent') , 0.120
# item: ('sandwich bags', 'vegetables', 'cheeses') , 0.120
# item: ('vegetables', 'soap', 'waffles') , 0.120
# item: ('poultry', 'vegetables', 'individual meals') , 0.120
# item: ('vegetables', 'bagels', 'aluminum foil') , 0.120
# item: ('vegetables', 'aluminum foil', 'waffles') , 0.120
# item: ('laundry detergent', 'vegetables', 'shampoo') , 0.120
# item: ('poultry', 'vegetables', 'all- purpose') , 0.120
# item: ('laundry detergent', 'dinner rolls', 'vegetables') , 0.120
# item: ('beef', 'all- purpose') , 0.121
# item: ('sugar', 'milk') , 0.121
# item: ('fruits', 'pasta') , 0.121
# item: ('hand soap', 'beef') , 0.121
# item: ('hand soap', 'cheeses') , 0.121
# item: ('hand soap', 'ice cream') , 0.121
# item: ('laundry detergent', 'hand soap') , 0.121
# item: ('tortillas', 'pork') , 0.121
# item: ('laundry detergent', 'pork') , 0.121
# item: ('sandwich bags', 'flour') , 0.121
# item: ('sandwich loaves', 'sandwich bags') , 0.121
# item: ('tortillas', 'dishwashing liquid/detergent') , 0.121
# item: ('sugar', 'pasta') , 0.121
# item: ('dinner rolls', 'cheeses', 'vegetables') , 0.121
# item: ('vegetables', 'yogurt', 'waffles') , 0.121
# item: ('vegetables', 'paper towels', 'eggs') , 0.121
# item: ('vegetables', 'soda', 'individual meals') , 0.121
# item: ('vegetables', 'cheeses', 'ice cream') , 0.121
# item: ('vegetables', 'cereals', 'yogurt') , 0.121
# item: ('spaghetti sauce', 'vegetables', 'juice') , 0.121
# item: ('laundry detergent', 'tortillas') , 0.122
# item: ('paper towels', 'pork') , 0.122
# item: ('beef', 'tortillas') , 0.122
# item: ('tortillas', 'ice cream') , 0.122
# item: ('flour', 'shampoo') , 0.122
# item: ('paper towels', 'flour') , 0.122
# item: ('pork', 'flour') , 0.122
# item: ('pasta', 'shampoo') , 0.122
# item: ('fruits', 'flour') , 0.122
# item: ('mixes', 'sugar') , 0.122
# item: ('butter', 'dishwashing liquid/detergent') , 0.122
# item: ('flour', 'lunch meat') , 0.122
# item: ('poultry', 'vegetables', 'shampoo') , 0.122
# item: ('vegetables', 'eggs', 'pasta') , 0.122
# item: ('vegetables', 'soda', 'yogurt') , 0.122
# item: ('vegetables', 'bagels', 'eggs') , 0.122
# item: ('vegetables', 'soda', 'soap') , 0.122
# item: ('vegetables', 'eggs', 'ketchup') , 0.122
# item: ('sandwich loaves', 'bagels') , 0.123
# item: ('sugar', 'bagels') , 0.123
# item: ('pork', 'shampoo') , 0.123
# item: ('sandwich loaves', 'fruits') , 0.123
# item: ('toilet paper', 'pasta') , 0.123
# item: ('juice', 'pasta') , 0.123
# item: ('sandwich loaves', 'toilet paper') , 0.123
# item: ('sandwich bags', 'toilet paper') , 0.123
# item: ('paper towels', 'sugar') , 0.123
# item: ('sandwich loaves', 'lunch meat') , 0.123
# item: ('laundry detergent', 'beef') , 0.123
# item: ('toilet paper', 'pork') , 0.123
# item: ('butter', 'aluminum foil') , 0.123
# item: ('dinner rolls', 'fruits') , 0.123
# item: ('fruits', 'individual meals') , 0.123
# item: ('sugar', 'all- purpose') , 0.123
# item: ('spaghetti sauce', 'coffee/tea') , 0.123
# item: ('mixes', 'pasta') , 0.123
# item: ('juice', 'tortillas') , 0.123
# item: ('tortillas', 'yogurt') , 0.123
# item: ('poultry', 'sandwich loaves', 'vegetables') , 0.123
# item: ('poultry', 'vegetables', 'milk') , 0.123
# item: ('juice', 'vegetables', 'shampoo') , 0.123
# item: ('juice', 'vegetables', 'yogurt') , 0.123
# item: ('vegetables', 'milk', 'yogurt') , 0.123
# item: ('juice', 'vegetables', 'aluminum foil') , 0.123
# item: ('vegetables', 'soap', 'eggs') , 0.123
# item: ('vegetables', 'eggs', 'milk') , 0.123
# item: ('vegetables', 'cereals', 'lunch meat') , 0.123
# item: ('hand soap', 'individual meals') , 0.124
# item: ('hand soap', 'lunch meat') , 0.124
# item: ('flour', 'pasta') , 0.124
# item: ('pork', 'lunch meat') , 0.124
# item: ('dishwashing liquid/detergent', 'shampoo') , 0.124
# item: ('bagels', 'pasta') , 0.124
# item: ('pork', 'individual meals') , 0.124
# item: ('fruits', 'shampoo') , 0.124
# item: ('flour', 'ice cream') , 0.124
# item: ('tortillas', 'aluminum foil') , 0.124
# item: ('shampoo', 'milk') , 0.124
# item: ('hand soap', 'ketchup') , 0.124
# item: ('tortillas', 'sugar') , 0.124
# item: ('poultry', 'vegetables', 'cereals') , 0.124
# item: ('vegetables', 'eggs', 'waffles') , 0.124
# item: ('vegetables', 'cheeses', 'waffles') , 0.124
# item: ('poultry', 'vegetables', 'cheeses') , 0.124
# item: ('sandwich bags', 'pasta') , 0.125
# item: ('sandwich loaves', 'paper towels') , 0.125
# item: ('soap', 'pork') , 0.125
# item: ('juice', 'milk') , 0.125
# item: ('flour', 'eggs') , 0.125
# item: ('hand soap', 'coffee/tea') , 0.125
# item: ('juice', 'sugar') , 0.125
# item: ('spaghetti sauce', 'all- purpose') , 0.125
# item: ('spaghetti sauce', 'pork') , 0.125
# item: ('beef', 'individual meals') , 0.125
# item: ('hand soap', 'waffles') , 0.125
# item: ('sandwich bags', 'eggs') , 0.125
# item: ('toilet paper', 'flour') , 0.125
# item: ('butter', 'ketchup') , 0.125
# item: ('flour', 'individual meals') , 0.125
# item: ('juice', 'butter') , 0.125
# item: ('poultry', 'vegetables', 'soda') , 0.125
# item: ('juice', 'vegetables', 'eggs') , 0.125
# item: ('vegetables', 'cheeses', 'yogurt') , 0.125
# item: ('individual meals', 'milk') , 0.125
# item: ('sugar', 'aluminum foil') , 0.125
# item: ('tortillas', 'butter') , 0.125
# item: ('butter', 'ice cream') , 0.125
# item: ('sandwich loaves', 'mixes') , 0.125
# item: ('ketchup', 'individual meals') , 0.125
# item: ('butter', 'individual meals') , 0.125
# item: ('sandwich loaves', 'all- purpose') , 0.125
# item: ('sandwich bags', 'butter') , 0.125
# item: ('butter', 'all- purpose') , 0.125
# item: ('laundry detergent', 'flour') , 0.125
# item: ('beef', 'pasta') , 0.125
# item: ('sandwich loaves', 'butter') , 0.125
# item: ('laundry detergent', 'vegetables', 'cereals') , 0.125
# item: ('vegetables', 'mixes', 'aluminum foil') , 0.125
# item: ('poultry', 'vegetables', 'yogurt') , 0.125
# item: ('hand soap', 'mixes') , 0.126
# item: ('juice', 'sandwich bags') , 0.126
# item: ('aluminum foil', 'lunch meat') , 0.126
# item: ('lunch meat', 'ketchup') , 0.126
# item: ('soda', 'butter') , 0.126
# item: ('sandwich bags', 'all- purpose') , 0.126
# item: ('juice', 'cheeses') , 0.126
# item: ('beef', 'sandwich loaves') , 0.126
# item: ('sandwich bags', 'individual meals') , 0.126
# item: ('cereals', 'butter') , 0.126
# item: ('tortillas', 'eggs') , 0.126
# item: ('butter', 'bagels') , 0.126
# item: ('sandwich bags', 'aluminum foil') , 0.126
# item: ('tortillas', 'soap') , 0.126
# item: ('laundry detergent', 'coffee/tea') , 0.126
# item: ('cereals', 'flour') , 0.126
# item: ('sugar', 'shampoo') , 0.126
# item: ('tortillas', 'waffles') , 0.126
# item: ('butter', 'coffee/tea') , 0.126
# item: ('pork', 'dishwashing liquid/detergent') , 0.126
# item: ('sugar', 'flour') , 0.126
# item: ('flour', 'all- purpose') , 0.126
# item: ('vegetables', 'soda', 'dinner rolls') , 0.126
# item: ('poultry', 'vegetables', 'coffee/tea') , 0.126
# item: ('pasta', 'milk') , 0.127
# item: ('sandwich loaves', 'dinner rolls') , 0.127
# item: ('sandwich loaves', 'sugar') , 0.127
# item: ('sandwich loaves', 'waffles') , 0.127
# item: ('laundry detergent', 'fruits') , 0.127
# item: ('butter', 'waffles') , 0.127
# item: ('laundry detergent', 'sugar') , 0.127
# item: ('spaghetti sauce', 'ice cream') , 0.127
# item: ('sugar', 'individual meals') , 0.127
# item: ('tortillas', 'individual meals') , 0.127
# item: ('tortillas', 'cereals') , 0.127
# item: ('sandwich loaves', 'coffee/tea') , 0.127
# item: ('dinner rolls', 'pork') , 0.127
# item: ('tortillas', 'milk') , 0.127
# item: ('juice', 'dishwashing liquid/detergent') , 0.127
# item: ('vegetables', 'cheeses', 'eggs') , 0.127
# item: ('poultry', 'vegetables', 'lunch meat') , 0.127
# item: ('poultry', 'vegetables', 'aluminum foil') , 0.127
# item: ('dishwashing liquid/detergent', 'flour') , 0.128
# item: ('sugar', 'dishwashing liquid/detergent') , 0.128
# item: ('sugar', 'fruits') , 0.128
# item: ('spaghetti sauce', 'beef') , 0.128
# item: ('flour', 'waffles') , 0.128
# item: ('beef', 'pork') , 0.128
# item: ('beef', 'coffee/tea') , 0.128
# item: ('tortillas', 'ketchup') , 0.128
# item: ('sugar', 'eggs') , 0.128
# item: ('poultry', 'vegetables', 'ice cream') , 0.128
# item: ('waffles', 'milk') , 0.129
# item: ('flour', 'milk') , 0.129
# item: ('tortillas', 'lunch meat') , 0.129
# item: ('dishwashing liquid/detergent', 'ketchup') , 0.129
# item: ('bagels', 'all- purpose') , 0.129
# item: ('aluminum foil', 'pasta') , 0.129
# item: ('spaghetti sauce', 'toilet paper') , 0.129
# item: ('hand soap', 'milk') , 0.129
# item: ('mixes', 'ice cream') , 0.129
# item: ('soda', 'all- purpose') , 0.129
# item: ('laundry detergent', 'butter') , 0.129
# item: ('spaghetti sauce', 'fruits') , 0.129
# item: ('toilet paper', 'dishwashing liquid/detergent') , 0.129
# item: ('pork', 'eggs') , 0.129
# item: ('laundry detergent', 'paper towels') , 0.129
# item: ('spaghetti sauce', 'butter') , 0.129
# item: ('bagels', 'yogurt') , 0.129
# item: ('spaghetti sauce', 'milk') , 0.129
# item: ('poultry', 'vegetables', 'sugar') , 0.129
# item: ('dinner rolls', 'vegetables', 'waffles') , 0.129
# item: ('poultry', 'vegetables', 'soap') , 0.129
# item: ('eggs', 'individual meals') , 0.130
# item: ('toilet paper', 'sugar') , 0.130
# item: ('sandwich bags', 'pork') , 0.130
# item: ('butter', 'paper towels') , 0.130
# item: ('cheeses', 'pork') , 0.130
# item: ('tortillas', 'toilet paper') , 0.130
# item: ('fruits', 'coffee/tea') , 0.130
# item: ('soda', 'fruits') , 0.130
# item: ('soda', 'pork') , 0.130
# item: ('sandwich loaves', 'ketchup') , 0.130
# item: ('sandwich bags', 'ice cream') , 0.130
# item: ('pork', 'yogurt') , 0.130
# item: ('ketchup', 'yogurt') , 0.130
# item: ('laundry detergent', 'pasta') , 0.130
# item: ('sandwich loaves', 'aluminum foil') , 0.130
# item: ('sandwich bags', 'dinner rolls') , 0.130
# item: ('fruits', 'ketchup') , 0.130
# item: ('cereals', 'ketchup') , 0.130
# item: ('tortillas', 'soda') , 0.130
# item: ('fruits', 'eggs') , 0.130
# item: ('dinner rolls', 'vegetables', 'eggs') , 0.130
# item: ('beef', 'mixes') , 0.131
# item: ('sandwich bags', 'lunch meat') , 0.131
# item: ('soap', 'yogurt') , 0.131
# item: ('sandwich loaves', 'soda') , 0.131
# item: ('sandwich bags', 'mixes') , 0.131
# item: ('dishwashing liquid/detergent', 'yogurt') , 0.131
# item: ('soda', 'lunch meat') , 0.131
# item: ('all- purpose', 'shampoo') , 0.131
# item: ('sandwich bags', 'dishwashing liquid/detergent') , 0.131
# item: ('laundry detergent', 'spaghetti sauce') , 0.131
# item: ('all- purpose', 'coffee/tea') , 0.131
# item: ('pork', 'ketchup') , 0.131
# item: ('spaghetti sauce', 'paper towels') , 0.131
# item: ('butter', 'shampoo') , 0.131
# item: ('sugar', 'coffee/tea') , 0.131
# item: ('sandwich bags', 'bagels') , 0.131
# item: ('juice', 'sandwich loaves') , 0.131
# item: ('mixes', 'waffles') , 0.131
# item: ('sandwich bags', 'coffee/tea') , 0.131
# item: ('laundry detergent', 'ice cream') , 0.131
# item: ('eggs', 'shampoo') , 0.131
# item: ('all- purpose', 'milk') , 0.131
# item: ('sandwich bags', 'shampoo') , 0.131
# item: ('fruits', 'soap') , 0.131
# item: ('vegetables', 'aluminum foil', 'yogurt') , 0.131
# item: ('poultry', 'vegetables', 'juice') , 0.131
# item: ('laundry detergent', 'vegetables', 'poultry') , 0.131
# item: ('spaghetti sauce', 'sandwich loaves') , 0.132
# item: ('cheeses', 'all- purpose') , 0.132
# item: ('paper towels', 'yogurt') , 0.132
# item: ('cereals', 'pork') , 0.132
# item: ('juice', 'mixes') , 0.132
# item: ('paper towels', 'fruits') , 0.132
# item: ('hand soap', 'dinner rolls') , 0.132
# item: ('dinner rolls', 'butter') , 0.132
# item: ('aluminum foil', 'pork') , 0.132
# item: ('soda', 'shampoo') , 0.132
# item: ('cheeses', 'dishwashing liquid/detergent') , 0.132
# item: ('paper towels', 'bagels') , 0.132
# item: ('bagels', 'soap') , 0.132
# item: ('ice cream', 'yogurt') , 0.132
# item: ('cereals', 'sugar') , 0.132
# item: ('dinner rolls', 'lunch meat') , 0.132
# item: ('shampoo', 'coffee/tea') , 0.132
# item: ('lunch meat', 'shampoo') , 0.132
# item: ('soap', 'flour') , 0.132
# item: ('butter', 'mixes') , 0.132
# item: ('poultry', 'vegetables', 'eggs') , 0.132
# item: ('paper towels', 'shampoo') , 0.132
# item: ('juice', 'lunch meat') , 0.132
# item: ('beef', 'bagels') , 0.132
# item: ('spaghetti sauce', 'yogurt') , 0.132
# item: ('cheeses', 'pasta') , 0.132
# item: ('bagels', 'pork') , 0.132
# item: ('eggs', 'lunch meat') , 0.132
# item: ('beef', 'dishwashing liquid/detergent') , 0.132
# item: ('spaghetti sauce', 'ketchup') , 0.132
# item: ('cheeses', 'milk') , 0.132
# item: ('flour', 'coffee/tea') , 0.132
# item: ('dinner rolls', 'toilet paper') , 0.132
# item: ('hand soap', 'poultry') , 0.132
# item: ('tortillas', 'paper towels') , 0.132
# item: ('sandwich loaves', 'yogurt') , 0.132
# item: ('laundry detergent', 'individual meals') , 0.132
# item: ('laundry detergent', 'bagels') , 0.132
# item: ('sandwich loaves', 'cereals') , 0.132
# item: ('beef', 'paper towels') , 0.132
# item: ('laundry detergent', 'toilet paper') , 0.132
# item: ('mixes', 'fruits') , 0.132
# item: ('ice cream', 'shampoo') , 0.132
# item: ('all- purpose', 'pasta') , 0.132
# item: ('beef', 'soda') , 0.132
# item: ('pork', 'waffles') , 0.132
# item: ('spaghetti sauce', 'individual meals') , 0.132
# item: ('fruits', 'milk') , 0.132
# item: ('mixes', 'coffee/tea') , 0.132
# item: ('vegetables', 'eggs', 'yogurt') , 0.132
# item: ('poultry', 'vegetables', 'mixes') , 0.132
# item: ('lunch meat', 'all- purpose') , 0.133
# item: ('cheeses', 'shampoo') , 0.133
# item: ('bagels', 'shampoo') , 0.133
# item: ('toilet paper', 'all- purpose') , 0.133
# item: ('bagels', 'coffee/tea') , 0.133
# item: ('beef', 'waffles') , 0.133
# item: ('yogurt', 'pasta') , 0.133
# item: ('fruits', 'yogurt') , 0.133
# item: ('individual meals', 'coffee/tea') , 0.133
# item: ('bagels', 'milk') , 0.133
# item: ('poultry', 'flour') , 0.133
# item: ('sugar', 'soap') , 0.133
# item: ('sugar', 'ice cream') , 0.133
# item: ('mixes', 'soap') , 0.133
# item: ('mixes', 'bagels') , 0.133
# item: ('flour', 'ketchup') , 0.133
# item: ('mixes', 'pork') , 0.133
# item: ('laundry detergent', 'lunch meat') , 0.133
# item: ('all- purpose', 'ice cream') , 0.133
# item: ('paper towels', 'dishwashing liquid/detergent') , 0.133
# item: ('mixes', 'flour') , 0.133
# item: ('beef', 'shampoo') , 0.133
# item: ('tortillas', 'bagels') , 0.133
# item: ('dinner rolls', 'all- purpose') , 0.133
# item: ('spaghetti sauce', 'pasta') , 0.133
# item: ('pasta', 'coffee/tea') , 0.133
# item: ('milk', 'coffee/tea') , 0.133
# item: ('paper towels', 'pasta') , 0.133
# item: ('yogurt', 'shampoo') , 0.133
# item: ('dishwashing liquid/detergent', 'individual meals') , 0.133
# item: ('soda', 'sugar') , 0.133
# item: ('dinner rolls', 'milk') , 0.133
# item: ('fruits', 'aluminum foil') , 0.133
# item: ('butter', 'eggs') , 0.133
# item: ('dinner rolls', 'tortillas') , 0.133
# item: ('mixes', 'all- purpose') , 0.133
# item: ('cereals', 'all- purpose') , 0.133
# item: ('aluminum foil', 'flour') , 0.133
# item: ('soda', 'bagels') , 0.134
# item: ('pork', 'coffee/tea') , 0.134
# item: ('aluminum foil', 'shampoo') , 0.134
# item: ('bagels', 'lunch meat') , 0.134
# item: ('cereals', 'soda') , 0.134
# item: ('soda', 'mixes') , 0.134
# item: ('beef', 'ketchup') , 0.134
# item: ('shampoo', 'individual meals') , 0.134
# item: ('toilet paper', 'butter') , 0.134
# item: ('aluminum foil', 'all- purpose') , 0.134
# item: ('beef', 'dinner rolls') , 0.134
# item: ('soap', 'aluminum foil') , 0.134
# item: ('lunch meat', 'milk') , 0.134
# item: ('toilet paper', 'ice cream') , 0.134
# item: ('dinner rolls', 'flour') , 0.134
# item: ('bagels', 'waffles') , 0.134
# item: ('paper towels', 'individual meals') , 0.134
# item: ('soda', 'flour') , 0.134
# item: ('lunch meat', 'yogurt') , 0.134
# item: ('paper towels', 'cheeses') , 0.134
# item: ('dishwashing liquid/detergent', 'pasta') , 0.134
# item: ('dinner rolls', 'individual meals') , 0.134
# item: ('toilet paper', 'shampoo') , 0.134
# item: ('aluminum foil', 'eggs') , 0.134
# item: ('beef', 'milk') , 0.134
# item: ('beef', 'eggs') , 0.134
# item: ('dinner rolls', 'bagels') , 0.134
# item: ('vegetables', 'lunch meat', 'waffles') , 0.134
# item: ('bagels', 'fruits') , 0.135
# item: ('sandwich bags', 'ketchup') , 0.135
# item: ('sandwich bags', 'yogurt') , 0.135
# item: ('beef', 'cheeses') , 0.135
# item: ('tortillas', 'coffee/tea') , 0.135
# item: ('ketchup', 'shampoo') , 0.135
# item: ('poultry', 'pasta') , 0.135
# item: ('bagels', 'ketchup') , 0.135
# item: ('all- purpose', 'ketchup') , 0.135
# item: ('sugar', 'cheeses') , 0.135
# item: ('ketchup', 'milk') , 0.135
# item: ('ice cream', 'ketchup') , 0.135
# item: ('ice cream', 'milk') , 0.135
# item: ('butter', 'soap') , 0.135
# item: ('butter', 'cheeses') , 0.135
# item: ('mixes', 'individual meals') , 0.135
# item: ('juice', 'coffee/tea') , 0.135
# item: ('beef', 'sugar') , 0.135
# item: ('laundry detergent', 'aluminum foil') , 0.135
# item: ('sandwich bags', 'paper towels') , 0.135
# item: ('pork', 'all- purpose') , 0.135
# item: ('soda', 'paper towels') , 0.135
# item: ('toilet paper', 'mixes') , 0.135
# item: ('sandwich loaves', 'soap') , 0.135
# item: ('spaghetti sauce', 'aluminum foil') , 0.135
# item: ('poultry', 'vegetables', 'dishwashing liquid/detergent') , 0.135
# item: ('vegetables', 'soda', 'eggs') , 0.135
# item: ('sandwich loaves', 'shampoo') , 0.136
# item: ('mixes', 'eggs') , 0.136
# item: ('paper towels', 'coffee/tea') , 0.136
# item: ('beef', 'lunch meat') , 0.136
# item: ('cheeses', 'lunch meat') , 0.136
# item: ('toilet paper', 'yogurt') , 0.136
# item: ('laundry detergent', 'yogurt') , 0.136
# item: ('juice', 'beef') , 0.136
# item: ('ice cream', 'pasta') , 0.136
# item: ('fruits', 'all- purpose') , 0.136
# item: ('laundry detergent', 'ketchup') , 0.136
# item: ('sandwich bags', 'tortillas') , 0.136
# item: ('spaghetti sauce', 'soda') , 0.136
# item: ('toilet paper', 'ketchup') , 0.136
# item: ('laundry detergent', 'cheeses') , 0.136
# item: ('dinner rolls', 'ice cream') , 0.136
# item: ('spaghetti sauce', 'cheeses') , 0.136
# item: ('fruits', 'lunch meat') , 0.136
# item: ('paper towels', 'ketchup') , 0.136
# item: ('soap', 'shampoo') , 0.136
# item: ('aluminum foil', 'ketchup') , 0.137
# item: ('shampoo', 'waffles') , 0.137
# item: ('beef', 'yogurt') , 0.137
# item: ('sandwich bags', 'cereals') , 0.137
# item: ('laundry detergent', 'soda') , 0.137
# item: ('cereals', 'bagels') , 0.137
# item: ('aluminum foil', 'dishwashing liquid/detergent') , 0.137
# item: ('dinner rolls', 'pasta') , 0.137
# item: ('toilet paper', 'bagels') , 0.137
# item: ('laundry detergent', 'waffles') , 0.137
# item: ('spaghetti sauce', 'mixes') , 0.137
# item: ('sandwich loaves', 'cheeses') , 0.137
# item: ('juice', 'paper towels') , 0.137
# item: ('juice', 'pork') , 0.137
# item: ('soda', 'ketchup') , 0.137
# item: ('mixes', 'shampoo') , 0.137
# item: ('sandwich bags', 'fruits') , 0.137
# item: ('eggs', 'coffee/tea') , 0.138
# item: ('beef', 'aluminum foil') , 0.138
# item: ('cereals', 'pasta') , 0.138
# item: ('mixes', 'cheeses') , 0.138
# item: ('beef', 'sandwich bags') , 0.138
# item: ('beef', 'soap') , 0.138
# item: ('juice', 'all- purpose') , 0.138
# item: ('mixes', 'lunch meat') , 0.138
# item: ('cereals', 'shampoo') , 0.138
# item: ('spaghetti sauce', 'lunch meat') , 0.138
# item: ('juice', 'soda') , 0.138
# item: ('juice', 'cereals') , 0.138
# item: ('spaghetti sauce', 'eggs') , 0.138
# item: ('laundry detergent', 'mixes') , 0.138
# item: ('spaghetti sauce', 'soap') , 0.138
# item: ('toilet paper', 'aluminum foil') , 0.138
# item: ('ice cream', 'coffee/tea') , 0.138
# item: ('eggs', 'all- purpose') , 0.138
# item: ('laundry detergent', 'juice') , 0.138
# item: ('mixes', 'yogurt') , 0.138
# item: ('soda', 'toilet paper') , 0.138
# item: ('spaghetti sauce', 'bagels') , 0.138
# item: ('toilet paper', 'individual meals') , 0.138
# item: ('laundry detergent', 'eggs') , 0.138
# item: ('poultry', 'dinner rolls', 'vegetables') , 0.138
# item: ('ketchup', 'pasta') , 0.139
# item: ('soap', 'pasta') , 0.139
# item: ('juice', 'soap') , 0.139
# item: ('yogurt', 'individual meals') , 0.139
# item: ('dishwashing liquid/detergent', 'coffee/tea') , 0.139
# item: ('sugar', 'lunch meat') , 0.139
# item: ('dinner rolls', 'dishwashing liquid/detergent') , 0.139
# item: ('butter', 'lunch meat') , 0.139
# item: ('fruits', 'waffles') , 0.139
# item: ('bagels', 'ice cream') , 0.139
# item: ('dinner rolls', 'paper towels') , 0.139
# item: ('poultry', 'butter') , 0.139
# item: ('laundry detergent', 'shampoo') , 0.139
# item: ('laundry detergent', 'soap') , 0.139
# ...
# Rule: ('soda', 'cheeses') ==> ('vegetables',) , 0.805
# Rule: ('toilet paper', 'mixes') ==> ('vegetables',) , 0.805
# Rule: ('sandwich bags', 'aluminum foil') ==> ('vegetables',) , 0.806
# Rule: ('cereals', 'flour') ==> ('vegetables',) , 0.806
# Rule: ('butter', 'coffee/tea') ==> ('vegetables',) , 0.806
# Rule: ('cheeses', 'waffles') ==> ('vegetables',) , 0.806
# Rule: ('poultry', 'ketchup') ==> ('vegetables',) , 0.806
# Rule: ('cheeses', 'flour') ==> ('vegetables',) , 0.806
# Rule: ('laundry detergent', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.806
# Rule: ('paper towels', 'coffee/tea') ==> ('vegetables',) , 0.806
# Rule: ('cheeses', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.807
# Rule: ('dinner rolls', 'butter') ==> ('vegetables',) , 0.807
# Rule: ('hand soap', 'dinner rolls') ==> ('vegetables',) , 0.807
# Rule: ('laundry detergent', 'sugar') ==> ('vegetables',) , 0.807
# Rule: ('poultry', 'toilet paper') ==> ('vegetables',) , 0.807
# Rule: ('juice', 'bagels') ==> ('vegetables',) , 0.807
# Rule: ('dinner rolls', 'pasta') ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent', 'individual meals') ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent', 'bagels') ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent', 'toilet paper') ==> ('vegetables',) , 0.808
# Rule: ('dinner rolls', 'toilet paper') ==> ('vegetables',) , 0.808
# Rule: ('dishwashing liquid/detergent', 'lunch meat') ==> ('vegetables',) , 0.808
# Rule: ('dishwashing liquid/detergent', 'shampoo') ==> ('vegetables',) , 0.809
# Rule: ('toilet paper', 'eggs') ==> ('vegetables',) , 0.809
# Rule: ('cereals', 'shampoo') ==> ('vegetables',) , 0.809
# Rule: ('spaghetti sauce', 'bagels') ==> ('vegetables',) , 0.809
# Rule: ('cereals', 'pasta') ==> ('vegetables',) , 0.809
# Rule: ('paper towels', 'pasta') ==> ('vegetables',) , 0.809
# Rule: ('soda', 'all- purpose') ==> ('vegetables',) , 0.810
# Rule: ('juice', 'waffles') ==> ('vegetables',) , 0.810
# Rule: ('sandwich bags', 'pasta') ==> ('vegetables',) , 0.810
# Rule: ('poultry', 'butter') ==> ('vegetables',) , 0.810
# Rule: ('dinner rolls', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.810
# Rule: ('sandwich loaves', 'ketchup') ==> ('vegetables',) , 0.811
# Rule: ('bagels', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.811
# Rule: ('cheeses', 'individual meals') ==> ('vegetables',) , 0.811
# Rule: ('eggs',) ==> ('vegetables',) , 0.811
# Rule: ('poultry', 'soda') ==> ('vegetables',) , 0.811
# Rule: ('spaghetti sauce', 'aluminum foil') ==> ('vegetables',) , 0.812
# Rule: ('dinner rolls', 'cheeses') ==> ('vegetables',) , 0.812
# Rule: ('cheeses', 'ice cream') ==> ('vegetables',) , 0.812
# Rule: ('sandwich bags', 'lunch meat') ==> ('vegetables',) , 0.812
# Rule: ('soda', 'pasta') ==> ('vegetables',) , 0.812
# Rule: ('aluminum foil', 'milk') ==> ('vegetables',) , 0.812
# Rule: ('sandwich loaves', 'ice cream') ==> ('vegetables',) , 0.812
# Rule: ('sugar', 'shampoo') ==> ('vegetables',) , 0.812
# Rule: ('tortillas', 'eggs') ==> ('vegetables',) , 0.812
# Rule: ('soap', 'flour') ==> ('vegetables',) , 0.813
# Rule: ('laundry detergent', 'milk') ==> ('vegetables',) , 0.814
# Rule: ('juice', 'shampoo') ==> ('vegetables',) , 0.814
# Rule: ('sandwich loaves', 'cheeses') ==> ('vegetables',) , 0.814
# Rule: ('waffles', 'shampoo') ==> ('vegetables',) , 0.814
# Rule: ('sandwich loaves', 'fruits') ==> ('vegetables',) , 0.814
# Rule: ('flour', 'coffee/tea') ==> ('vegetables',) , 0.815
# Rule: ('spaghetti sauce', 'lunch meat') ==> ('vegetables',) , 0.815
# Rule: ('spaghetti sauce', 'soap') ==> ('vegetables',) , 0.815
# Rule: ('sandwich bags', 'cheeses') ==> ('vegetables',) , 0.815
# Rule: ('paper towels', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.816
# Rule: ('soda', 'sugar') ==> ('vegetables',) , 0.816
# Rule: ('cheeses', 'shampoo') ==> ('vegetables',) , 0.816
# Rule: ('dinner rolls', 'milk') ==> ('vegetables',) , 0.816
# Rule: ('lunch meat', 'all- purpose') ==> ('vegetables',) , 0.816
# Rule: ('cheeses', 'ketchup') ==> ('vegetables',) , 0.816
# Rule: ('pork', 'eggs') ==> ('vegetables',) , 0.816
# Rule: ('individual meals', 'yogurt') ==> ('vegetables',) , 0.816
# Rule: ('yogurt', 'coffee/tea') ==> ('vegetables',) , 0.816
# Rule: ('sandwich loaves', 'individual meals') ==> ('vegetables',) , 0.816
# Rule: ('dinner rolls', 'paper towels') ==> ('vegetables',) , 0.816
# Rule: ('soda', 'individual meals') ==> ('vegetables',) , 0.817
# Rule: ('dinner rolls', 'bagels') ==> ('vegetables',) , 0.817
# Rule: ('aluminum foil', 'all- purpose') ==> ('vegetables',) , 0.817
# Rule: ('mixes', 'aluminum foil') ==> ('vegetables',) , 0.817
# Rule: ('laundry detergent', 'pasta') ==> ('vegetables',) , 0.818
# Rule: ('sugar', 'yogurt') ==> ('vegetables',) , 0.818
# Rule: ('poultry', 'bagels') ==> ('vegetables',) , 0.818
# Rule: ('sandwich bags', 'paper towels') ==> ('vegetables',) , 0.818
# Rule: ('spaghetti sauce', 'waffles') ==> ('vegetables',) , 0.818
# Rule: ('paper towels', 'aluminum foil') ==> ('vegetables',) , 0.818
# Rule: ('cereals', 'lunch meat') ==> ('vegetables',) , 0.819
# Rule: ('dinner rolls', 'sugar') ==> ('vegetables',) , 0.819
# Rule: ('sandwich loaves', 'soda') ==> ('vegetables',) , 0.819
# Rule: ('all- purpose', 'milk') ==> ('vegetables',) , 0.819
# Rule: ('aluminum foil', 'ice cream') ==> ('vegetables',) , 0.819
# Rule: ('paper towels', 'lunch meat') ==> ('vegetables',) , 0.819
# Rule: ('spaghetti sauce', 'poultry') ==> ('vegetables',) , 0.819
# Rule: ('mixes', 'eggs') ==> ('vegetables',) , 0.819
# Rule: ('fruits', 'lunch meat') ==> ('vegetables',) , 0.819
# Rule: ('sandwich bags', 'individual meals') ==> ('vegetables',) , 0.819
# Rule: ('sandwich bags', 'waffles') ==> ('vegetables',) , 0.820
# Rule: ('juice', 'mixes') ==> ('vegetables',) , 0.820
# Rule: ('flour', 'shampoo') ==> ('vegetables',) , 0.820
# Rule: ('poultry', 'individual meals') ==> ('vegetables',) , 0.820
# Rule: ('aluminum foil', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.821
# Rule: ('aluminum foil', 'ketchup') ==> ('vegetables',) , 0.821
# Rule: ('sandwich loaves', 'sugar') ==> ('vegetables',) , 0.821
# Rule: ('sandwich loaves', 'waffles') ==> ('vegetables',) , 0.821
# Rule: ('sugar', 'waffles') ==> ('vegetables',) , 0.821
# Rule: ('waffles', 'yogurt') ==> ('vegetables',) , 0.821
# Rule: ('laundry detergent', 'mixes') ==> ('vegetables',) , 0.822
# Rule: ('cheeses', 'aluminum foil') ==> ('vegetables',) , 0.822
# Rule: ('soda', 'aluminum foil') ==> ('vegetables',) , 0.822
# Rule: ('yogurt', 'shampoo') ==> ('vegetables',) , 0.822
# Rule: ('shampoo', 'milk') ==> ('vegetables',) , 0.823
# Rule: ('tortillas', 'sugar') ==> ('vegetables',) , 0.823
# Rule: ('hand soap', 'ketchup') ==> ('vegetables',) , 0.823
# Rule: ('laundry detergent', 'soap') ==> ('vegetables',) , 0.823
# Rule: ('bagels', 'yogurt') ==> ('vegetables',) , 0.823
# Rule: ('dinner rolls', 'yogurt') ==> ('vegetables',) , 0.823
# Rule: ('soda', 'flour') ==> ('vegetables',) , 0.824
# Rule: ('sandwich loaves', 'aluminum foil') ==> ('vegetables',) , 0.824
# Rule: ('pork', 'yogurt') ==> ('vegetables',) , 0.824
# Rule: ('eggs', 'waffles') ==> ('vegetables',) , 0.825
# Rule: ('soda', 'paper towels') ==> ('vegetables',) , 0.825
# Rule: ('juice', 'coffee/tea') ==> ('vegetables',) , 0.825
# Rule: ('dinner rolls', 'aluminum foil') ==> ('vegetables',) , 0.825
# Rule: ('sandwich loaves', 'butter') ==> ('vegetables',) , 0.825
# Rule: ('sandwich bags', 'shampoo') ==> ('vegetables',) , 0.826
# Rule: ('soap', 'yogurt') ==> ('vegetables',) , 0.826
# Rule: ('cheeses', 'yogurt') ==> ('vegetables',) , 0.826
# Rule: ('cheeses', 'lunch meat') ==> ('vegetables',) , 0.826
# Rule: ('paper towels', 'all- purpose') ==> ('vegetables',) , 0.826
# Rule: ('sandwich bags', 'flour') ==> ('vegetables',) , 0.826
# Rule: ('laundry detergent', 'all- purpose') ==> ('vegetables',) , 0.826
# Rule: ('poultry', 'dinner rolls') ==> ('vegetables',) , 0.826
# Rule: ('lunch meat', 'ketchup') ==> ('vegetables',) , 0.826
# Rule: ('butter', 'mixes') ==> ('vegetables',) , 0.827
# Rule: ('soda', 'shampoo') ==> ('vegetables',) , 0.827
# Rule: ('yogurt', 'ice cream') ==> ('vegetables',) , 0.827
# Rule: ('lunch meat', 'shampoo') ==> ('vegetables',) , 0.827
# Rule: ('beef', 'yogurt') ==> ('vegetables',) , 0.827
# Rule: ('lunch meat', 'ice cream') ==> ('vegetables',) , 0.827
# Rule: ('poultry', 'shampoo') ==> ('vegetables',) , 0.827
# Rule: ('paper towels', 'shampoo') ==> ('vegetables',) , 0.828
# Rule: ('spaghetti sauce', 'yogurt') ==> ('vegetables',) , 0.828
# Rule: ('soda', 'eggs') ==> ('vegetables',) , 0.828
# Rule: ('paper towels', 'sugar') ==> ('vegetables',) , 0.829
# Rule: ('spaghetti sauce', 'pasta') ==> ('vegetables',) , 0.829
# Rule: ('laundry detergent', 'lunch meat') ==> ('vegetables',) , 0.829
# Rule: ('all- purpose', 'ice cream') ==> ('vegetables',) , 0.829
# Rule: ('mixes', 'flour') ==> ('vegetables',) , 0.829
# Rule: ('poultry', 'paper towels') ==> ('vegetables',) , 0.829
# Rule: ('poultry', 'ice cream') ==> ('vegetables',) , 0.830
# Rule: ('hand soap', 'individual meals') ==> ('vegetables',) , 0.830
# Rule: ('aluminum foil', 'pasta') ==> ('vegetables',) , 0.830
# Rule: ('lunch meat', 'milk') ==> ('vegetables',) , 0.830
# Rule: ('beef', 'eggs') ==> ('vegetables',) , 0.830
# Rule: ('bagels', 'lunch meat') ==> ('vegetables',) , 0.830
# Rule: ('aluminum foil', 'waffles') ==> ('vegetables',) , 0.830
# Rule: ('sandwich loaves', 'paper towels') ==> ('vegetables',) , 0.831
# Rule: ('spaghetti sauce', 'juice') ==> ('vegetables',) , 0.831
# Rule: ('eggs', 'shampoo') ==> ('vegetables',) , 0.832
# Rule: ('sandwich loaves', 'shampoo') ==> ('vegetables',) , 0.832
# Rule: ('soda', 'yogurt') ==> ('vegetables',) , 0.832
# Rule: ('eggs', 'ketchup') ==> ('vegetables',) , 0.832
# Rule: ('poultry', 'coffee/tea') ==> ('vegetables',) , 0.832
# Rule: ('laundry detergent', 'poultry') ==> ('vegetables',) , 0.832
# Rule: ('soap', 'lunch meat') ==> ('vegetables',) , 0.833
# Rule: ('laundry detergent', 'soda') ==> ('vegetables',) , 0.833
# Rule: ('all- purpose', 'yogurt') ==> ('vegetables',) , 0.834
# Rule: ('eggs', 'coffee/tea') ==> ('vegetables',) , 0.834
# Rule: ('juice', 'lunch meat') ==> ('vegetables',) , 0.834
# Rule: ('juice', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.834
# Rule: ('sandwich loaves', 'coffee/tea') ==> ('vegetables',) , 0.834
# Rule: ('poultry', 'sugar') ==> ('vegetables',) , 0.835
# Rule: ('bagels', 'aluminum foil') ==> ('vegetables',) , 0.835
# Rule: ('sugar', 'ice cream') ==> ('vegetables',) , 0.836
# Rule: ('sugar', 'eggs') ==> ('vegetables',) , 0.836
# Rule: ('sandwich loaves', 'lunch meat') ==> ('vegetables',) , 0.836
# Rule: ('tortillas', 'yogurt') ==> ('vegetables',) , 0.836
# Rule: ('lunch meat', 'waffles') ==> ('vegetables',) , 0.836
# Rule: ('dinner rolls', 'flour') ==> ('vegetables',) , 0.837
# Rule: ('laundry detergent', 'paper towels') ==> ('vegetables',) , 0.837
# Rule: ('eggs', 'pasta') ==> ('vegetables',) , 0.837
# Rule: ('bagels', 'eggs') ==> ('vegetables',) , 0.837
# Rule: ('poultry', 'pasta') ==> ('vegetables',) , 0.838
# Rule: ('sandwich bags', 'yogurt') ==> ('vegetables',) , 0.838
# Rule: ('juice', 'milk') ==> ('vegetables',) , 0.838
# Rule: ('sandwich loaves', 'flour') ==> ('vegetables',) , 0.838
# Rule: ('juice', 'yogurt') ==> ('vegetables',) , 0.838
# Rule: ('spaghetti sauce', 'soda') ==> ('vegetables',) , 0.839
# Rule: ('laundry detergent', 'spaghetti sauce') ==> ('vegetables',) , 0.839
# Rule: ('laundry detergent', 'flour') ==> ('vegetables',) , 0.839
# Rule: ('sugar', 'aluminum foil') ==> ('vegetables',) , 0.839
# Rule: ('hand soap', 'eggs') ==> ('vegetables',) , 0.839
# Rule: ('juice', 'paper towels') ==> ('vegetables',) , 0.840
# Rule: ('laundry detergent', 'coffee/tea') ==> ('vegetables',) , 0.840
# Rule: ('laundry detergent', 'dinner rolls') ==> ('vegetables',) , 0.840
# Rule: ('laundry detergent', 'eggs') ==> ('vegetables',) , 0.841
# Rule: ('cheeses', 'pasta') ==> ('vegetables',) , 0.841
# Rule: ('paper towels', 'flour') ==> ('vegetables',) , 0.842
# Rule: ('dinner rolls', 'soda') ==> ('vegetables',) , 0.842
# Rule: ('aluminum foil', 'flour') ==> ('vegetables',) , 0.842
# Rule: ('poultry', 'flour') ==> ('vegetables',) , 0.842
# Rule: ('juice', 'ketchup') ==> ('vegetables',) , 0.843
# Rule: ('flour', 'yogurt') ==> ('vegetables',) , 0.843
# Rule: ('poultry', 'aluminum foil') ==> ('vegetables',) , 0.843
# Rule: ('juice', 'aluminum foil') ==> ('vegetables',) , 0.843
# Rule: ('poultry', 'mixes') ==> ('vegetables',) , 0.844
# Rule: ('hand soap', 'lunch meat') ==> ('vegetables',) , 0.844
# Rule: ('cereals', 'eggs') ==> ('vegetables',) , 0.845
# Rule: ('poultry', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.846
# Rule: ('poultry', 'yogurt') ==> ('vegetables',) , 0.846
# Rule: ('paper towels', 'yogurt') ==> ('vegetables',) , 0.847
# Rule: ('dinner rolls', 'lunch meat') ==> ('vegetables',) , 0.847
# Rule: ('spaghetti sauce', 'eggs') ==> ('vegetables',) , 0.847
# Rule: ('aluminum foil', 'lunch meat') ==> ('vegetables',) , 0.847
# Rule: ('poultry', 'eggs') ==> ('vegetables',) , 0.847
# Rule: ('sandwich loaves', 'yogurt') ==> ('vegetables',) , 0.848
# Rule: ('sugar', 'milk') ==> ('vegetables',) , 0.848
# Rule: ('poultry', 'lunch meat') ==> ('vegetables',) , 0.848
# Rule: ('sugar', 'lunch meat') ==> ('vegetables',) , 0.848
# Rule: ('sandwich loaves', 'dinner rolls') ==> ('vegetables',) , 0.848
# Rule: ('poultry', 'sandwich loaves') ==> ('vegetables',) , 0.848
# Rule: ('soap', 'eggs') ==> ('vegetables',) , 0.848
# Rule: ('butter', 'eggs') ==> ('vegetables',) , 0.849
# Rule: ('flour', 'ketchup') ==> ('vegetables',) , 0.849
# Rule: ('flour', 'lunch meat') ==> ('vegetables',) , 0.849
# Rule: ('laundry detergent', 'sandwich bags') ==> ('vegetables',) , 0.849
# Rule: ('lunch meat', 'yogurt') ==> ('vegetables',) , 0.850
# Rule: ('aluminum foil', 'shampoo') ==> ('vegetables',) , 0.850
# Rule: ('butter', 'aluminum foil') ==> ('vegetables',) , 0.850
# Rule: ('laundry detergent', 'aluminum foil') ==> ('vegetables',) , 0.851
# Rule: ('eggs', 'individual meals') ==> ('vegetables',) , 0.851
# Rule: ('fruits', 'eggs') ==> ('vegetables',) , 0.851
# Rule: ('yogurt', 'ketchup') ==> ('vegetables',) , 0.851
# Rule: ('aluminum foil', 'yogurt') ==> ('vegetables',) , 0.851
# Rule: ('paper towels', 'ketchup') ==> ('vegetables',) , 0.852
# Rule: ('laundry detergent', 'ketchup') ==> ('vegetables',) , 0.852
# Rule: ('flour', 'eggs') ==> ('vegetables',) , 0.852
# Rule: ('laundry detergent', 'ice cream') ==> ('vegetables',) , 0.852
# Rule: ('laundry detergent', 'waffles') ==> ('vegetables',) , 0.853
# Rule: ('eggs', 'milk') ==> ('vegetables',) , 0.854
# Rule: ('pasta', 'yogurt') ==> ('vegetables',) , 0.855
# Rule: ('laundry detergent', 'cereals') ==> ('vegetables',) , 0.856
# Rule: ('poultry', 'juice') ==> ('vegetables',) , 0.856
# Rule: ('laundry detergent', 'butter') ==> ('vegetables',) , 0.857
# Rule: ('laundry detergent', 'cheeses') ==> ('vegetables',) , 0.858
# Rule: ('spaghetti sauce', 'pork') ==> ('vegetables',) , 0.859
# Rule: ('dinner rolls', 'waffles') ==> ('vegetables',) , 0.860
# Rule: ('all- purpose', 'eggs') ==> ('vegetables',) , 0.860
# Rule: ('dinner rolls', 'eggs') ==> ('vegetables',) , 0.860
# Rule: ('dishwashing liquid/detergent', 'eggs') ==> ('vegetables',) , 0.861
# Rule: ('juice', 'dinner rolls') ==> ('vegetables',) , 0.861
# Rule: ('paper towels', 'eggs') ==> ('vegetables',) , 0.863
# Rule: ('aluminum foil', 'eggs') ==> ('vegetables',) , 0.863
# Rule: ('laundry detergent', 'yogurt') ==> ('vegetables',) , 0.865
# Rule: ('pork', 'lunch meat') ==> ('vegetables',) , 0.865
# Rule: ('soda', 'lunch meat') ==> ('vegetables',) , 0.866
# Rule: ('juice', 'eggs') ==> ('vegetables',) , 0.866
# Rule: ('sandwich bags', 'eggs') ==> ('vegetables',) , 0.866
# Rule: ('juice', 'butter') ==> ('vegetables',) , 0.866
# Rule: ('juice', 'laundry detergent') ==> ('vegetables',) , 0.866
# Rule: ('laundry detergent', 'shampoo') ==> ('vegetables',) , 0.867
# Rule: ('yogurt', 'milk') ==> ('vegetables',) , 0.875
# Rule: ('sugar', 'flour') ==> ('vegetables',) , 0.875
# Rule: ('sugar', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.877
# Rule: ('cheeses', 'eggs') ==> ('vegetables',) , 0.879
# Rule: ('dishwashing liquid/detergent', 'yogurt') ==> ('vegetables',) , 0.879
# Rule: ('eggs', 'lunch meat') ==> ('vegetables',) , 0.881
# Rule: ('eggs', 'yogurt') ==> ('vegetables',) , 0.883
# Rule: ('sandwich loaves', 'eggs') ==> ('vegetables',) , 0.886

# %%
print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #') 
print ('Case 3 (minimum support=0.29 and minimum confidence=0.1)')
print ('Case 3 Reasoning:')
print('Here is the maximum value possible for support is evaluated, keeping the confidence minimum.')
print('It is sure that it directly affected the number of items.')
print('Even if the confidence is minimum, the rules derived are very much less compared to other two cases.')
print('If I increase the value from 0.29, it derives no rules.')
print ('\nCase 3 Output:')
# %run apriori.py -f DATASET.csv -s 0.29 -c 0.1
# Out:
# # # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #
# Case 3 (minimum support=0.29 and minimum confidence=0.1)
# Case 3 Reasoning:
# Here is the maximum value possible for support is evaluated, keeping the confidence minimum.
# It is sure that it directly affected the number of items.
# Even if the confidence is minimum, the rules derived are very much less compared to other two cases.
# If I increase the value from 0.29, it derives no rules.
#
# Case 3 Output:
#
# ------------ITEMS-----------------
# item: ('poultry', 'vegetables') , 0.296
# item: ('hand soap',) , 0.310
# item: ('flour',) , 0.320
# item: ('sandwich loaves',) , 0.323
# item: ('tortillas',) , 0.325
# item: ('pasta',) , 0.326
# item: ('pork',) , 0.327
# item: ('sugar',) , 0.330
# item: ('paper towels',) , 0.333
# item: ('sandwich bags',) , 0.334
# item: ('butter',) , 0.334
# item: ('spaghetti sauce',) , 0.334
# item: ('fruits',) , 0.339
# item: ('shampoo',) , 0.340
# item: ('ketchup',) , 0.341
# item: ('laundry detergent',) , 0.343
# item: ('beef',) , 0.345
# item: ('juice',) , 0.345
# item: ('all- purpose',) , 0.345
# item: ('milk',) , 0.347
# item: ('toilet paper',) , 0.347
# item: ('bagels',) , 0.348
# item: ('lunch meat',) , 0.350
# item: ('individual meals',) , 0.351
# item: ('yogurt',) , 0.351
# item: ('aluminum foil',) , 0.351
# item: ('dishwashing liquid/detergent',) , 0.351
# item: ('mixes',) , 0.351
# item: ('eggs',) , 0.354
# item: ('coffee/tea',) , 0.354
# item: ('soap',) , 0.355
# item: ('cheeses',) , 0.355
# item: ('soda',) , 0.356
# item: ('dinner rolls',) , 0.356
# item: ('ice cream',) , 0.357
# item: ('waffles',) , 0.364
# item: ('cereals',) , 0.368
# item: ('poultry',) , 0.383
# item: ('vegetables',) , 0.687
#
# ------------RULES-----------------
# Rule: ('vegetables',) ==> ('poultry',) , 0.430
# Rule: ('poultry',) ==> ('vegetables',) , 0.771

# %% [markdown]
# # References
#
# [01] https://www.kaggle.com/acostasg/random-shopping-cart
#
# [02] https://github.com/asaini/Apriori

# %% [markdown]
# # Rubric
# * [02 points] - Student Details
# * [08 points] - Comply with submission instructions
# * [30 points] - DataSet Preprocess
# * [30 points] - Run apriory.py
# * [30 points] - Evaluate Results
